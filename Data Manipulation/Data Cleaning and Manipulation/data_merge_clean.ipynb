# %%
# code by Peter Solis

# %%
# dependencies
import pandas as pd
from datetime import datetime as dt

# %%
# MERGING - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# pull 3 CSVs to dataframes
IDs_df = pd.read_csv('../Raw Data/2000s_US_IDs.csv')
credits_df = pd.read_csv('../Raw Data/movie_credits.csv')
details_df = pd.read_csv('../Raw Data/movie_details.csv')

details_df.head()
# Out:
#    Unnamed: 0  Movie ID     Budget    Revenue    Genre 1    Genre 2  \
# 0           0     11688  100000000  169327687  Adventure  Animation
# 1           1      4247   19000000  278019771     Comedy        NaN
# 2           2      9600   30000000  173959438      Crime     Comedy
# 3           3        98  103000000  465361176     Action      Drama
# 4           4      3134          0     940944      Crime      Drama
#
#      Genre 3   Genre 4  Genre 5 Release Date  Run Time
# 0     Comedy    Family  Fantasy   2000-12-15        78
# 1        NaN       NaN      NaN   2000-07-07        88
# 2        NaN       NaN      NaN   2000-05-31        98
# 3  Adventure       NaN      NaN   2000-05-04       155
# 4    Romance  Thriller      NaN   2000-06-28        77

# %%
# delete extra index column in credits & details
credits_df = credits_df.drop(columns=['Unnamed: 0'])
details_df = details_df.drop(columns=['Unnamed: 0'])

details_df.head()
# Out:
#    Movie ID     Budget    Revenue    Genre 1    Genre 2    Genre 3   Genre 4  \
# 0     11688  100000000  169327687  Adventure  Animation     Comedy    Family
# 1      4247   19000000  278019771     Comedy        NaN        NaN       NaN
# 2      9600   30000000  173959438      Crime     Comedy        NaN       NaN
# 3        98  103000000  465361176     Action      Drama  Adventure       NaN
# 4      3134          0     940944      Crime      Drama    Romance  Thriller
#
#    Genre 5 Release Date  Run Time
# 0  Fantasy   2000-12-15        78
# 1      NaN   2000-07-07        88
# 2      NaN   2000-05-31        98
# 3      NaN   2000-05-04       155
# 4      NaN   2000-06-28        77

# %%
print(len(IDs_df))
print(len(credits_df))
print(len(details_df))
# Out:
# 4407
# 4407
# 4407

# %%
# merge 3 dataframes
merge_df_1 = pd.merge(IDs_df,
                    details_df,
                    on='Movie ID',
                    how='left')
merge_df_2 = pd.merge(merge_df_1,
                    credits_df,
                    on='Movie ID',
                    how='left')

merge_df_2.shape
# Out:
# (4407, 21)

# %%
# CLEANING - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# purge movies that have no budget or revenue data
money_condition = (
    (merge_df_2['Budget'] > 0) & 
    (merge_df_2['Revenue'] > 0))
with_money_df = merge_df_2[money_condition]

with_money_df.shape
# Out:
# (2601, 21)

# %%
# parse date
dates = pd.to_datetime(with_money_df['Release Date'],
                       format = '%Y-%m-%d')

with_date_df = with_money_df.drop(columns = ['Release Year', 'Release Date'])
with_date_df['Release Date'] = dates
with_date_df['Release Day'] = dates.dt.day
with_date_df['Release Month'] = dates.dt.month
with_date_df['Release Year'] = dates.dt.year

with_date_df.head()
# Out:
#    Movie ID                     Title  Popularity Score  Average Rating  \
# 0     11688  The Emperor's New Groove            86.051             7.5
# 1      4247               Scary Movie            88.909             6.3
# 2      9600         Big Momma's House            81.102             5.8
# 3        98                 Gladiator            67.513             8.2
# 6       955    Mission: Impossible II            64.994             6.1
#
#    Number of Ratings     Budget    Revenue    Genre 1    Genre 2    Genre 3  \
# 0               6007  100000000  169327687  Adventure  Animation     Comedy
# 1               6247   19000000  278019771     Comedy        NaN        NaN
# 2               2096   30000000  173959438      Crime     Comedy        NaN
# 3              16708  103000000  465361176     Action      Drama  Adventure
# 6               5985  125000000  546388105  Adventure     Action   Thriller
#
#    ...          Actor 1          Actor 2          Actor 3            Actor 4  \
# 0  ...      David Spade     John Goodman      Eartha Kitt  Patrick Warburton
# 1  ...       Anna Faris     Jon Abrahams    Marlon Wayans       Shawn Wayans
# 2  ...  Martin Lawrence         Nia Long    Paul Giamatti  Jascha Washington
# 3  ...    Russell Crowe  Joaquin Phoenix   Connie Nielsen        Oliver Reed
# 6  ...       Tom Cruise    Dougray Scott  Thandiwe Newton        Ving Rhames
#
#             Actor 5             Director Release Date Release Day  \
# 0     Wendie Malick          Mark Dindal   2000-12-15          15
# 1       Regina Hall  Keenen Ivory Wayans   2000-07-07           7
# 2   Terrence Howard         Raja Gosnell   2000-05-31          31
# 3    Richard Harris         Ridley Scott   2000-05-04           4
# 6  Richard Roxburgh             John Woo   2000-05-24          24
#
#   Release Month Release Year
# 0            12         2000
# 1             7         2000
# 2             5         2000
# 3             5         2000
# 6             5         2000
#
# [5 rows x 23 columns]

# %%
# no made-for-TV movies
tv_condition = (
    (with_date_df['Genre 1'] != 'TV Movie') |
    (with_date_df['Genre 2'] != 'TV Movie') |
    (with_date_df['Genre 3'] != 'TV Movie') |
    (with_date_df['Genre 4'] != 'TV Movie') |
    (with_date_df['Genre 5'] != 'TV Movie'))
no_tv_df = with_date_df[tv_condition]

no_tv_df.shape
# Out:
# (2601, 23)

# %%
# make sure we have actors / some genre
details_condition = (
    (no_tv_df['Actor 1'].notna()) &
    (no_tv_df['Genre 1'].notna()))
has_details_df = no_tv_df[details_condition]

has_details_df.shape
# Out:
# (2601, 23)

# %%
# list data types
has_details_df.dtypes
# Out:
# Movie ID                      int64
# Title                        object
# Popularity Score            float64
# Average Rating              float64
# Number of Ratings             int64
# Budget                        int64
# Revenue                       int64
# Genre 1                      object
# Genre 2                      object
# Genre 3                      object
# Genre 4                      object
# Genre 5                      object
# Run Time                      int64
# Actor 1                      object
# Actor 2                      object
# Actor 3                      object
# Actor 4                      object
# Actor 5                      object
# Director                     object
# Release Date         datetime64[ns]
# Release Day                   int64
# Release Month                 int64
# Release Year                  int64
# dtype: object

# %%
# make columns for:
# net revenue 
net_rev = has_details_df['Revenue'] - has_details_df['Budget']
# net revenue as a % over budget (0 = movie broke even with budget)
net_rev_percent = net_rev / has_details_df['Budget']

has_details_df['Net Revenue'] = net_rev
has_details_df['Net Revenue (% Over Budget)'] = net_rev_percent

has_details_df.head()
# Out:
#    Movie ID                     Title  Popularity Score  Average Rating  \
# 0     11688  The Emperor's New Groove            86.051             7.5
# 1      4247               Scary Movie            88.909             6.3
# 2      9600         Big Momma's House            81.102             5.8
# 3        98                 Gladiator            67.513             8.2
# 6       955    Mission: Impossible II            64.994             6.1
#
#    Number of Ratings     Budget    Revenue    Genre 1    Genre 2    Genre 3  \
# 0               6007  100000000  169327687  Adventure  Animation     Comedy
# 1               6247   19000000  278019771     Comedy        NaN        NaN
# 2               2096   30000000  173959438      Crime     Comedy        NaN
# 3              16708  103000000  465361176     Action      Drama  Adventure
# 6               5985  125000000  546388105  Adventure     Action   Thriller
#
#    ...          Actor 3            Actor 4           Actor 5  \
# 0  ...      Eartha Kitt  Patrick Warburton     Wendie Malick
# 1  ...    Marlon Wayans       Shawn Wayans       Regina Hall
# 2  ...    Paul Giamatti  Jascha Washington   Terrence Howard
# 3  ...   Connie Nielsen        Oliver Reed    Richard Harris
# 6  ...  Thandiwe Newton        Ving Rhames  Richard Roxburgh
#
#               Director Release Date Release Day Release Month Release Year  \
# 0          Mark Dindal   2000-12-15          15            12         2000
# 1  Keenen Ivory Wayans   2000-07-07           7             7         2000
# 2         Raja Gosnell   2000-05-31          31             5         2000
# 3         Ridley Scott   2000-05-04           4             5         2000
# 6             John Woo   2000-05-24          24             5         2000
#
#   Net Revenue Net Revenue (% Over Budget)
# 0    69327687                    0.693277
# 1   259019771                   13.632620
# 2   143959438                    4.798648
# 3   362361176                    3.518070
# 6   421388105                    3.371105
#
# [5 rows x 25 columns]

# %%
# runtime of at least 1 hour
runtime_condition = (has_details_df['Run Time'] >= 60)
good_length_df = has_details_df[runtime_condition]

good_length_df.shape
# Out:
# (2601, 25)

# %%
# at least 250 user reviews
review_condition = (good_length_df['Number of Ratings'] >= 250)
review_count_df = good_length_df[review_condition]

review_count_df.shape
# Out:
# (2524, 25)

# %%
# list columns for reference
review_count_df.columns
# Out:
# Index(['Movie ID', 'Title', 'Popularity Score', 'Average Rating',
#        'Number of Ratings', 'Budget', 'Revenue', 'Genre 1', 'Genre 2',
#        'Genre 3', 'Genre 4', 'Genre 5', 'Run Time', 'Actor 1', 'Actor 2',
#        'Actor 3', 'Actor 4', 'Actor 5', 'Director', 'Release Date',
#        'Release Day', 'Release Month', 'Release Year', 'Net Revenue',
#        'Net Revenue (% Over Budget)'],
#       dtype='object')

# %%
# make final df (sort columns)
final_df = review_count_df[[
    # movie identifiers
    'Movie ID',
    'Title',
    # success-related statistics
    'Average Rating',
    'Number of Ratings',
    'Popularity Score',
    'Revenue',
    'Net Revenue',
    'Net Revenue (% Over Budget)',
    # variables
    'Budget',
    'Release Date',
    'Release Day',
    'Release Month',
    'Release Year',
    'Genre 1',
    'Genre 2',
    'Genre 3',
    'Genre 4',
    'Genre 5',
    'Run Time',
    'Actor 1',
    'Actor 2',
    'Actor 3',
    'Actor 4',
    'Actor 5',
    'Director']]

final_df.shape
# Out:
# (2524, 25)

# %%
# rename columns where needed
final_df = final_df.rename(columns = {'Average Rating': 'Average Rating (Out of 10)',
                                      'Popularity Score': 'TMDb Popularity Score',
                                      'Number of Ratings': 'Number of User Ratings',
                                      'Revenue': 'Gross Revenue',
                                      'Run Time': 'Runtime (Minutes)',
                                      'Actor 1': '1st Billing',
                                      'Actor 2': '2nd Billing',
                                      'Actor 3': '3rd Billing',
                                      'Actor 4': '4th Billing',
                                      'Actor 5': '5th Billing'})

# %%
# set movie ID to index & export
final_df = final_df.set_index('Movie ID')

#Add by Azi to drop year 2023
final_df = final_df.loc[final_df["Release Year"] != 2023]
final_df.to_csv('../Cleaned Data/cleaned_movie_data.csv')

final_df
# Out:
#                              Title  Average Rating (Out of 10)  \
# Movie ID
# 11688     The Emperor's New Groove                         7.5
# 4247                   Scary Movie                         6.3
# 9600             Big Momma's House                         5.8
# 98                       Gladiator                         8.2
# 955         Mission: Impossible II                         6.1
# ...                            ...                         ...
# 245842         The King's Daughter                         7.1
# 532710                 Firestarter                         5.7
# 766475            See How They Run                         6.4
# 744594                 White Noise                         5.6
# 833339               Speak No Evil                         6.7
#
#           Number of User Ratings  TMDb Popularity Score  Gross Revenue  \
# Movie ID
# 11688                       6007                 86.051      169327687
# 4247                        6247                 88.909      278019771
# 9600                        2096                 81.102      173959438
# 98                         16708                 67.513      465361176
# 955                         5985                 64.994      546388105
# ...                          ...                    ...            ...
# 245842                       631                 19.744        2182492
# 532710                       534                 20.793       15039250
# 766475                       808                 16.452       21921551
# 744594                       501                 16.168          71476
# 833339                       347                 17.336         623462
#
#           Net Revenue  Net Revenue (% Over Budget)     Budget Release Date  \
# Movie ID
# 11688        69327687                     0.693277  100000000   2000-12-15
# 4247        259019771                    13.632620   19000000   2000-07-07
# 9600        143959438                     4.798648   30000000   2000-05-31
# 98          362361176                     3.518070  103000000   2000-05-04
# 955         421388105                     3.371105  125000000   2000-05-24
# ...               ...                          ...        ...          ...
# 245842      -38317508                    -0.946111   40500000   2022-01-21
# 532710        3039250                     0.253271   12000000   2022-05-12
# 766475      -18078449                    -0.451961   40000000   2022-09-09
# 744594      -99928524                    -0.999285  100000000   2022-11-25
# 833339       -2376538                    -0.792179    3000000   2022-03-17
#
#           Release Day  ...          Genre 3  Genre 4  Genre 5  \
# Movie ID               ...
# 11688              15  ...           Comedy   Family  Fantasy
# 4247                7  ...              NaN      NaN      NaN
# 9600               31  ...              NaN      NaN      NaN
# 98                  4  ...        Adventure      NaN      NaN
# 955                24  ...         Thriller      NaN      NaN
# ...               ...  ...              ...      ...      ...
# 245842             21  ...           Family      NaN      NaN
# 532710             12  ...           Horror      NaN      NaN
# 766475              9  ...         Thriller      NaN      NaN
# 744594             25  ...  Science Fiction      NaN      NaN
# 833339             17  ...         Thriller      NaN      NaN
#
#          Runtime (Minutes)           1st Billing       2nd Billing  \
# Movie ID
# 11688                   78           David Spade      John Goodman
# 4247                    88            Anna Faris      Jon Abrahams
# 9600                    98       Martin Lawrence          Nia Long
# 98                     155         Russell Crowe   Joaquin Phoenix
# 955                    123            Tom Cruise     Dougray Scott
# ...                    ...                   ...               ...
# 245842                  94        Pierce Brosnan   Kaya Scodelario
# 532710                  94  Ryan Kiera Armstrong         Zac Efron
# 766475                  98          Sam Rockwell     Saoirse Ronan
# 744594                 136           Adam Driver      Greta Gerwig
# 833339                  97         Morten Burian  Sidsel Siem Koch
#
#               3rd Billing        4th Billing       5th Billing  \
# Movie ID
# 11688         Eartha Kitt  Patrick Warburton     Wendie Malick
# 4247        Marlon Wayans       Shawn Wayans       Regina Hall
# 9600        Paul Giamatti  Jascha Washington   Terrence Howard
# 98         Connie Nielsen        Oliver Reed    Richard Harris
# 955       Thandiwe Newton        Ving Rhames  Richard Roxburgh
# ...                   ...                ...               ...
# 245842    Benjamin Walker       William Hurt     Julie Andrews
# 532710      Sydney Lemmon     Kurtwood Smith  Michael Greyeyes
# 766475       Adrien Brody        Ruth Wilson  Reece Shearsmith
# 744594        Don Cheadle     Raffey Cassidy        Sam Nivola
# 833339     Fedja van Huêt    Karina Smulders     Liva Forsberg
#
#                      Director
# Movie ID
# 11688             Mark Dindal
# 4247      Keenen Ivory Wayans
# 9600             Raja Gosnell
# 98               Ridley Scott
# 955                  John Woo
# ...                       ...
# 245842          Sean McNamara
# 532710           Keith Thomas
# 766475             Tom George
# 744594          Noah Baumbach
# 833339      Christian Tafdrup
#
# [2490 rows x 24 columns]
