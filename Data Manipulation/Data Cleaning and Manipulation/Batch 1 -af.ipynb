# %%
# Project Title Next Movie Production

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Read the CSV and create first dataframe
firstdf = pd.read_csv("../Cleaned Data/cleaned_movie_data.csv")
#drop 2023 movies because we only have half year's worth of data for this year
firstdf = firstdf.loc[firstdf["Release Year"] != 2023]

# %%
firstdf.head(5)
# Out:
#    Movie ID                     Title  Average Rating (Out of 10)  \
# 0     11688  The Emperor's New Groove                         7.5
# 1      4247               Scary Movie                         6.3
# 2      9600         Big Momma's House                         5.8
# 3        98                 Gladiator                         8.2
# 4       955    Mission: Impossible II                         6.1
#
#    Number of User Ratings  TMDb Popularity Score  Gross Revenue  Net Revenue  \
# 0                    6007                 86.051      169327687     69327687
# 1                    6247                 88.909      278019771    259019771
# 2                    2096                 81.102      173959438    143959438
# 3                   16708                 67.513      465361176    362361176
# 4                    5985                 64.994      546388105    421388105
#
#    Net Revenue (% Over Budget)     Budget Release Date  ...    Genre 3  \
# 0                     0.693277  100000000   2000-12-15  ...     Comedy
# 1                    13.632620   19000000   2000-07-07  ...        NaN
# 2                     4.798648   30000000   2000-05-31  ...        NaN
# 3                     3.518070  103000000   2000-05-04  ...  Adventure
# 4                     3.371105  125000000   2000-05-24  ...   Thriller
#
#    Genre 4  Genre 5 Runtime (Minutes)      1st Billing      2nd Billing  \
# 0   Family  Fantasy                78      David Spade     John Goodman
# 1      NaN      NaN                88       Anna Faris     Jon Abrahams
# 2      NaN      NaN                98  Martin Lawrence         Nia Long
# 3      NaN      NaN               155    Russell Crowe  Joaquin Phoenix
# 4      NaN      NaN               123       Tom Cruise    Dougray Scott
#
#        3rd Billing        4th Billing       5th Billing             Director
# 0      Eartha Kitt  Patrick Warburton     Wendie Malick          Mark Dindal
# 1    Marlon Wayans       Shawn Wayans       Regina Hall  Keenen Ivory Wayans
# 2    Paul Giamatti  Jascha Washington   Terrence Howard         Raja Gosnell
# 3   Connie Nielsen        Oliver Reed    Richard Harris         Ridley Scott
# 4  Thandiwe Newton        Ving Rhames  Richard Roxburgh             John Woo
#
# [5 rows x 25 columns]

# %%
firstdf.dtypes
# Out:
# Movie ID                         int64
# Title                           object
# Average Rating (Out of 10)     float64
# Number of User Ratings           int64
# TMDb Popularity Score          float64
# Gross Revenue                    int64
# Net Revenue                      int64
# Net Revenue (% Over Budget)    float64
# Budget                           int64
# Release Date                    object
# Release Day                      int64
# Release Month                    int64
# Release Year                     int64
# Genre 1                         object
# Genre 2                         object
# Genre 3                         object
# Genre 4                         object
# Genre 5                         object
# Runtime (Minutes)                int64
# 1st Billing                     object
# 2nd Billing                     object
# 3rd Billing                     object
# 4th Billing                     object
# 5th Billing                     object
# Director                        object
# dtype: object

# %%
# Q1 Movie revenue by month?
# Create a graph that shows fluctations in revenue by month and year
# Ideas of info we can show:
    # What month has the highest and lowest revenue?
    # In the last 5 years, provide the highest grossing film or the year and month of release.
    # Accounting for peak COVID (2020-2021) - based on data, is there a significant change around this time in comparison to pre-covid (before 2020) and post-peak-covid (2022-2023)?

# %%
# Q1 Movie revenue by month?
#Start by creating a separate dataframe for Release Month, and Gross Revenue
rev_month_df = firstdf[["Release Month", "Gross Revenue"]].copy()

#Group the data by Month and run mean() method to obtain averages
grp_mnth = rev_month_df.groupby(["Release Month"])
rev_by_mnth = grp_mnth.mean()

#Build and show revenue by month averages based on rev_by_mnth 
months_labels = ["January", "February", "March", "April", "May", "June", "July",
                "August", "September", "October", "November", "December"]

#plot construction
x = np.arange(len(rev_by_mnth))
plt.bar(x, rev_by_mnth["Gross Revenue"])
plt.xticks(x, months_labels, rotation=45)
plt.xlabel("Monthly Average Gross Revenue (2000-2022)")
plt.ylabel("Revenue in Billion Dollars")
plt.title("Average Gross Revenues by Month")
plt.yscale("linear")
plt.grid(alpha=.2)
#export plot to image file
plt.savefig("../../Analysis/Visualizations/avg_rev_by_month.png", bbox_inches='tight')
#show the plot
plt.show()

# %%
# Q1 Movie revenue by year?
#Start by creating a separate dataframe for Release year, and Gross Revenue
rev_year_df = firstdf[["Release Year", "Gross Revenue"]].copy()

#Group the data by Year and run sum() method to obtain totals
grp_year = rev_year_df.groupby(["Release Year"])
rev_by_year = grp_year.sum()/1000000000 #get value in billions

#Build and show revenue by month averages based on rev_by_mnth 
year_labels = ["2000", "2001", "2002", "2003", "2004", "2005", "2006",
                "2007", "2008", "2009", "2010", "2011", "2012", "2013",
              "2014", "2015", "2016", "2017", "2018", "2019", "2020", "2021", "2022"]

#plot construction
x = np.arange(len(rev_by_year))
plt.bar(x, rev_by_year["Gross Revenue"])
plt.xticks(x, year_labels, rotation="vertical")
plt.xlabel("Year")
plt.ylabel("Revenue in Billion Dollars")
plt.title("Box Office Revenue")

plt.grid(alpha=.2)
#export plot to image file
plt.savefig("../../Analysis/Visualizations/rev_by_year.png", bbox_inches='tight')
#show the plot
plt.show()

# %% [markdown]
# Explorations on averages

# %%
rev_by_year
# Out:
#               Gross Revenue
# Release Year
# 2000              10.486669
# 2001              11.850216
# 2002              12.936351
# 2003              14.518924
# 2004              15.669232
# 2005              14.873361
# 2006              15.399851
# 2007              16.970609
# 2008              18.375401
# 2009              20.391576
# 2010              20.833546
# 2011              21.935461
# 2012              23.862867
# 2013              23.305877
# 2014              25.471605
# 2015              25.398150
# 2016              27.811581
# 2017              28.019558
# 2018              26.774742
# 2019              27.857184
# 2020               3.899910
# 2021              11.500274
# 2022              16.206604

# %%
#2019 to 2020 revenue difference
df_2019 = firstdf.loc[firstdf["Release Year"] == 2019]
rev_2019 = df_2019["Gross Revenue"].sum()/1000000000
df_2020 = firstdf.loc[firstdf["Release Year"] == 2020]
rev_2020 = df_2020["Gross Revenue"].sum()/1000000000
rev_diff_perc = round(((rev_2020-rev_2019)/rev_2019)*100)

print(f"Data shows there is a {rev_diff_perc}% change in gross revenue from 2019 to 2020.")
# Out:
# Data shows there is a -86% change in gross revenue from 2019 to 2020.

# %%
#Average number of movies released per month
avg_df = firstdf[["Release Year", "Release Month", "Title"]].copy()
avg_rel_grp = avg_df.groupby(["Release Month"])
avg_releases = avg_rel_grp.count()/23 #divide total number of releases over the years by the number of years
avg_releases
# Out:
#                Release Year      Title
# Release Month
# 1                  6.565217   6.565217
# 2                  8.173913   8.173913
# 3                  9.260870   9.260870
# 4                  6.652174   6.652174
# 5                  8.086957   8.086957
# 6                  9.260870   9.260870
# 7                  9.043478   9.043478
# 8                  9.695652   9.695652
# 9                 11.304348  11.304348
# 10                10.521739  10.521739
# 11                 9.304348   9.304348
# 12                10.391304  10.391304

# %%
#What month has the highest and lowest revenue? (on average)
rev_sorted = rev_by_mnth["Gross Revenue"].sort_values(ascending=False)
rev_sorted
print("May is the highest grossing month and September is the lowest gross month on average.")
# Out:
# May is the highest grossing month and September is the lowest gross month on average.

# %%
# In the last 5 years, provide the highest grossing film or the year and month of release.
last5years_df = firstdf.loc[(firstdf["Release Year"] == 2022) | (firstdf["Release Year"] == 2021) | (firstdf["Release Year"] == 2020)
                           | (firstdf["Release Year"] == 2019)| (firstdf["Release Year"] == 2018)]

sorted_last5 = last5years_df.sort_values("Gross Revenue", ascending=False)
hg_film = sorted_last5.iloc[0]
hg_title = hg_film["Title"]
hg_revenue = hg_film["Gross Revenue"]/1000000000 #get revenue in billions
hg_rd = hg_film["Release Date"]
hg_actor1 = hg_film["1st Billing"]
hg_actor2 = hg_film["2nd Billing"]
hg_actor3 = hg_film["3rd Billing"]
hg_actor4 = hg_film["4th Billing"]
hg_actor5 = hg_film["5th Billing"]
hg_director = hg_film["Director"]
hg_budget = hg_film["Budget"]/1000000000 #get budget in billions
hg_nr = hg_film["Net Revenue"]/1000000000
print(f"Highest grossing movie in the last 5 years is {hg_title}.")
print(f"{hg_title} cast includes {hg_actor1}, {hg_actor2}, {hg_actor3}, {hg_actor4}, {hg_actor5}, and was directed by {hg_director}.")
print(f"{hg_title}'s budget was ${hg_budget} billion dollars and box office revenue was ${hg_revenue} billion.")
print(f"Box office profts was ${hg_nr} billion.")
# Out:
# Highest grossing movie in the last 5 years is Avengers: Endgame.
# Avengers: Endgame cast includes Robert Downey Jr., Chris Evans, Mark Ruffalo, Chris Hemsworth, Scarlett Johansson, and was directed by Anthony Russo.
# Avengers: Endgame's budget was $0.356 billion dollars and box office revenue was $2.794731755 billion.
# Box office profts was $2.438731755 billion.

# %%
# Q2 Movie revenue by genre?
#Run code to see how many different genres are there for the primary genre
genredf = firstdf[["Gross Revenue", "Genre 1", "Release Year"]]
populargenres = firstdf["Genre 1"].value_counts()
populargenres
# Out:
# Action             497
# Drama              429
# Comedy             388
# Horror             223
# Adventure          210
# Animation          145
# Thriller           119
# Crime               93
# Science Fiction     91
# Fantasy             89
# Family              80
# Romance             48
# Mystery             29
# War                 23
# Music               12
# Western              7
# History              6
# Documentary          1
# Name: Genre 1, dtype: int64

# %% [markdown]
# Above shows most occurring genres over the last 23 years. For Genre analysis, we will look at the primary genre
# of the movie and look at the seven most popular.

# %%
#Analyze performance of the top 7 genres
topgenres = ["Action", "Drama", "Comedy", "Horror", "Adventure", "Animation", "Thriller"]

# Create empty list to fill with tumor vol data (for plotting)
revenues = []
genreoutliers = 0
# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for genre in topgenres:
    genrerevenue = firstdf.loc[firstdf["Genre 1"] == genre, "Gross Revenue"]
    revenues.append(genrerevenue)
    #calculate the statistics per drug regimen that we are looping through
    quartiles = genrerevenue.quantile([.25,.5,.75])
    lowerq = round(quartiles[0.25],6)
    upperq = round(quartiles[0.75], 6)
    iqr = round(upperq-lowerq, 6)

    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    
    #Locate outlisers
    #Determine outliers using upper and lower bounds and evaluating the tumor volume column
    outlierrows = firstdf.loc[firstdf["Genre 1"] == genre, ["Title", "Gross Revenue"]]
    outliers = outlierrows[(outlierrows['Gross Revenue'] >= upper_bound) | 
                                         (outlierrows['Gross Revenue'] <= lower_bound)]
    howmany = len(outliers)
    outliers.sort_values("Gross Revenue")
    print(f"Genre {genre} lower quartile is ${lowerq:,.2f}, upper quartile is ${upperq:,.2f} and has {howmany} outliers.")
    print(f"{genre} potential {howmany} outliers: {outliers}")
# Out:
# Genre Action lower quartile is $41,142,379.00, upper quartile is $288,500,217.00 and has 44 outliers.
# Action potential 44 outliers:                                           Title  Gross Revenue
# 363                                Spider-Man 2      788976453
# 854                                      Avatar     2923706026
# 862                                        2012      791217826
# 978                                   Inception      825532764
# 1089       Mission: Impossible - Ghost Protocol      694713380
# 1160             Transformers: Dark of the Moon     1123794079
# 1213                     The Amazing Spider-Man      757930663
# 1214                      The Dark Knight Rises     1081041287
# 1239                                    Skyfall     1142471295
# 1328                                 Iron Man 3     1215577205
# 1329                               Man of Steel      668045518
# 1457                   The Amazing Spider-Man 2      708962323
# 1458  The Hobbit: The Battle of the Five Armies      956019788
# 1477                 X-Men: Days of Future Past      747862775
# 1478                    Guardians of the Galaxy      772776600
# 1497        Captain America: The Winter Soldier      714766572
# 1593                    Avengers: Age of Ultron     1405403694
# 1595         Mission: Impossible - Rogue Nation      682716636
# 1597                                  Furious 7     1515341399
# 1601                             Jurassic World     1671537444
# 1619                                    Spectre      880674609
# 1714                                   Deadpool      783100000
# 1717         Batman v Superman: Dawn of Justice      873637528
# 1721                             Doctor Strange      676343174
# 1722                              Suicide Squad      746846894
# 1768               Rogue One: A Star Wars Story     1056057273
# 1866                     Spider-Man: Homecoming      880166924
# 1872                             Thor: Ragnarok      855301806
# 1878                    The Fate of the Furious     1236005118
# 1880                               Wonder Woman      822854286
# 1907                            Despicable Me 3     1031552585
# 2005              Mission: Impossible - Fallout      791657398
# 2007                                 Deadpool 2      785896609
# 2014             Jurassic World: Fallen Kingdom     1310466296
# 2023                              Incredibles 2     1242805359
# 2024                              Black Panther     1349926083
# 2025                                    Aquaman     1148528393
# 2138      Fast & Furious Presents: Hobbs & Shaw      760098996
# 2140                  Spider-Man: Far From Home     1131927996
# 2145                             Captain Marvel     1131416446
# 2317                    Spider-Man: No Way Home     1921847111
# 2344                                         F9      726229501
# 2408             Black Panther: Wakanda Forever      859102154
# 2412                          Top Gun: Maverick     1488732821
# Genre Drama lower quartile is $17,643,857.00, upper quartile is $123,726,688.00 and has 33 outliers.
# Drama potential 33 outliers:                                     Title  Gross Revenue
# 46                      What Lies Beneath      291420351
# 88                       A Beautiful Mind      316800000
# 162                   Catch Me If You Can      352114312
# 186                                 Signs      408247917
# 270                      The Last Samurai      456758981
# 341             The Passion of the Christ      611899420
# 544                          The Departed      291465000
# 557              The Pursuit of Happyness      307077295
# 655                           I Am Legend      585410052
# 747                       The Dark Knight     1004558444
# 763   The Curious Case of Benjamin Button      335802786
# 788                   Slumdog Millionaire      378410542
# 856                        The Blind Side      309208309
# 863                  Inglourious Basterds      321457747
# 988                        Shutter Island      294800000
# 1013                           Black Swan      329398046
# 1042                    The King's Speech      414211549
# 1105                     The Intouchables      426588510
# 1220                     Django Unchained      425368238
# 1359                     The Great Gatsby      351040419
# 1514                                 Noah      362637473
# 1589                 Fifty Shades of Grey      571006128
# 1612                          The Martian      630600000
# 1778                           Passengers      303144152
# 1819                               Dangal      311000000
# 1879                  Fifty Shades Darker      378827494
# 1897       War for the Planet of the Apes      490719763
# 1899                 The Greatest Showman      432844677
# 1910                               Wonder      305937718
# 1917         Murder on the Orient Express      352794081
# 2006                   Fifty Shades Freed      368307760
# 2037                           Green Book      319700000
# 2461                                Elvis      288670284
# Genre Comedy lower quartile is $40,845,298.75, upper quartile is $174,123,837.00 and has 13 outliers.
# Comedy potential 13 outliers:                                         Title  Gross Revenue
# 14                            What Women Want      374111707
# 381                          Meet the Fockers      516642939
# 759                          Sex and the City      415252786
# 776                                Mamma Mia!      609841637
# 859                              The Hangover      469310836
# 880   Alvin and the Chipmunks: The Squeakquel      443140005
# 982                       Shrek Forever After      752600867
# 1099                     The Hangover Part II      586764305
# 1223                                      Ted      549368315
# 1745                               La La Land      447407695
# 1776                              The Mermaid      553810228
# 2087              Mamma Mia! Here We Go Again      395044706
# 2166           Once Upon a Time… in Hollywood      374251247
# Genre Horror lower quartile is $28,825,287.50, upper quartile is $112,932,091.50 and has 13 outliers.
# Horror potential 13 outliers:                     Title  Gross Revenue
# 176              The Ring      249348933
# 343           Van Helsing      300257475
# 1324        The Conjuring      320406242
# 1489            Annabelle      257047661
# 1715      The Conjuring 2      321834351
# 1863                   It      701800000
# 1882  Annabelle: Creation      306515884
# 1885                Split      278454358
# 2008              The Nun      365582797
# 2029        A Quiet Place      341000000
# 2051            Halloween      259900000
# 2137       It Chapter Two      473122525
# 2188                   Us      256067149
# Genre Adventure lower quartile is $68,975,327.00, upper quartile is $488,653,435.50 and has 7 outliers.
# Adventure potential 7 outliers:                                               Title  Gross Revenue
# 240   The Lord of the Rings: The Return of the King     1118888979
# 1606                   Star Wars: The Force Awakens     2068223624
# 1719                     Captain America: Civil War     1153337496
# 1889                       Star Wars: The Last Jedi     1332698830
# 2004                         Avengers: Infinity War     2052415039
# 2133                              Avengers: Endgame     2794731755
# 2141                                  The Lion King     1663075401
# Genre Animation lower quartile is $68,514,844.00, upper quartile is $469,160,692.00 and has 1 outliers.
# Animation potential 1 outliers:        Title  Gross Revenue
# 1326  Frozen     1274219009
# Genre Thriller lower quartile is $14,414,223.50, upper quartile is $152,407,506.50 and has 7 outliers.
# Thriller potential 7 outliers:                                Title  Gross Revenue
# 83                Planet of the Apes      362211740
# 87                    Ocean's Eleven      450717150
# 373                   Ocean's Twelve      362744280
# 567                The Da Vinci Code      767820459
# 867                  Angels & Demons      485930816
# 1102  Rise of the Planet of the Apes      482860185
# 2274               Bad Boys for Life      426505244

# %%
#create boxplot for genre revenue
flierprop = dict(marker='o', markerfacecolor='red', markersize=8,
                  linestyle='none')
fig1, ax1 = plt.subplots()
ax1.set_ylabel('Gross Revenue (in Billions)')
ax1.boxplot(revenues, flierprops=flierprop)
ax1.set_xticklabels(topgenres)

#export plot to image file
plt.savefig("../../Analysis/Visualizations/rev_gen_boxplot.png", bbox_inches='tight')

#show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 7
#       5 ax1.set_ylabel('Gross Revenue (in Billions)')
#       6 ax1.boxplot(revenues, flierprops=flierprop)
# ----> 7 ax1.set_xticklabels(topgenres)
#       9 #export plot to image file
#      10 plt.savefig("../../Analysis/Visualizations/rev_gen_boxplot.png", bbox_inches='tight')
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/matplotlib/axes/_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:297, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     292     warn_deprecated(
#     293         since, message=f"The {old!r} parameter of {func.__name__}() "
#     294         f"has been renamed {new!r} since Matplotlib {since}; support "
#     295         f"for the old name will be dropped %(removal)s.")
#     296     kwargs[new] = kwargs.pop(old)
# --> 297 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/matplotlib/axis.py:1969, in Axis.set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    1965 if isinstance(locator, mticker.FixedLocator):
#    1966     # Passing [] as a list of labels is often used as a way to
#    1967     # remove all tick labels, so only error for > 0 labels
#    1968     if len(locator.locs) != len(labels) and len(labels) != 0:
# -> 1969         raise ValueError(
#    1970             "The number of FixedLocator locations"
#    1971             f" ({len(locator.locs)}), usually from a call to"
#    1972             " set_ticks, does not match"
#    1973             f" the number of labels ({len(labels)}).")
#    1974     tickd = {loc: lab for loc, lab in zip(locator.locs, labels)}
#    1975     func = functools.partial(self._format_with_dict, tickd)
#
# ValueError: The number of FixedLocator locations (1), usually from a call to set_ticks, does not match the number of labels (7).

# %%
#Analyze performance of the top 7 genres
topgenres = ["Action", "Drama", "Comedy", "Horror", "Adventure", "Animation", "Thriller"]

# Create empty list to fill with tumor vol data (for plotting)
revenues2 = []
genreoutliers = 0
# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for genre in topgenres:
    genrerevenue = firstdf.loc[firstdf["Genre 1"] == genre, "Gross Revenue"]
    revenues2.append(genrerevenue)
    #calculate the statistics per drug regimen that we are looping through
    quartiles = genrerevenue.quantile([.25,.5,.75])
    lowerq = round(quartiles[0.25],6)
    upperq = round(quartiles[0.75], 6)
    iqr = round(upperq-lowerq, 6)

    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    
    #Locate outlisers
    outlierrows = firstdf.loc[firstdf["Genre 1"] == genre, ["Title", "Gross Revenue"]]
    temparray = revenues2
    avgarray = np.array(temparray)
    avg = avgarray.mean()
#     Determine outliers using upper and lower bounds and evaluating the tumor volume column
    outliers = outlierrows[(outlierrows['Gross Revenue'] >= upper_bound) | 
                                         (outlierrows['Gross Revenue'] <= lower_bound)]
    howmany = len(outliers)
    outliers.sort_values("Gross Revenue")
    print(f"Genre {genre} lower quartile is ${lowerq:,.2f}, upper quartile is ${upperq:,.2f} and has {howmany} outliers.")
    print(f"Genre {genre} has average revenue of ${avg:,.2f}")
#     print(f"{genre} potential {howmany} outliers: {outliers}")
    temparray.clear() #reset the list
# Out:
# Genre Action lower quartile is $41,142,379.00, upper quartile is $288,500,217.00 and has 44 outliers.
# Genre Action has average revenue of $228,869,755.48
# Genre Drama lower quartile is $17,643,857.00, upper quartile is $123,726,688.00 and has 33 outliers.
# Genre Drama has average revenue of $93,960,028.39
# Genre Comedy lower quartile is $40,845,298.75, upper quartile is $174,123,837.00 and has 13 outliers.
# Genre Comedy has average revenue of $123,073,051.32
# Genre Horror lower quartile is $28,825,287.50, upper quartile is $112,932,091.50 and has 13 outliers.
# Genre Horror has average revenue of $84,853,619.16
# Genre Adventure lower quartile is $68,975,327.00, upper quartile is $488,653,435.50 and has 7 outliers.
# Genre Adventure has average revenue of $343,116,357.46
# Genre Animation lower quartile is $68,514,844.00, upper quartile is $469,160,692.00 and has 1 outliers.
# Genre Animation has average revenue of $290,414,567.72
# Genre Thriller lower quartile is $14,414,223.50, upper quartile is $152,407,506.50 and has 7 outliers.
# Genre Thriller has average revenue of $103,663,319.72
