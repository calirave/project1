# %%
# dependencies
import requests
import json
import pandas as pd
from pprint import pprint
from api_keys import api_key

# %%
# parameters
base_url = "https://api.themoviedb.org/3/discover/movie"
region = 'US'
years = range(2000,2024,1)
pages = range(1,100,1)

# empty list for movie ID, name, popularity, avg rating, # of votes, release year
movie_ids = []
movie_names = []
movie_pops = []
movie_vote_avgs = []
movie_vote_counts = []
movie_release_yrs = []

for year in years:
    # set variable to keep track of pages without results
    bad_page = 0
    for page in pages:
        # finish setting up parameters
        params = {
            'api_key':api_key,
            'include_adult':False,
            'region':region,
            'primary_release_year':year,
            'sort_by':'popularity.desc',
            'page':page
        }
        # get data for given year
        response = requests.get(base_url, params=params).json()
        
        # set variables to see if there's useful data on the page 
        movie_found = False
        
        # go through data
        try:
            # counter for movies that don't fit the requirements so it can break earlier
            bad_result = 0
            # loop through data
            for result in response['results']:
                if (result['popularity'] > 20) & (result['vote_count'] > 100):
                    movie_found = True
                    movie_ids.append(result['id'])
                    movie_names.append(result['title'])
                    movie_pops.append(result['popularity'])
                    movie_vote_avgs.append(result['vote_average'])
                    movie_vote_counts.append(result['vote_count'])
                    movie_release_yrs.append(year)
                else:
                    # if 10 results (half) on page don't fit requirements, move on
                    bad_result += 1
                    if bad_result >= 10:
                        break
                    else:
                        pass
        except:
            print(f'Had an issue getting data from {year}, page: {page}.')
            pass
        # print if no data was found on the page
        if movie_found:
            bad_page = 0
            print(f'Got data from year: {year}, page: {page}.')
        else:
            bad_page += 1
            print(f'Not enough useful data on year: {year}, page: {page}.')
        # skip to next year if multiple pages in a row with NO useful info
        if bad_page >= 2:
            print(f'Multiple pages w/o useful data, skipping the rest of {year}.')
            break
# Out:
# Got data from year: 2000, page: 1.
# Got data from year: 2000, page: 2.
# Got data from year: 2000, page: 3.
# Got data from year: 2000, page: 4.
# Not enough useful data on year: 2000, page: 5.
# Not enough useful data on year: 2000, page: 6.
# Multiple pages w/o useful data, skipping the rest of 2000.
# Got data from year: 2001, page: 1.
# Got data from year: 2001, page: 2.
# Got data from year: 2001, page: 3.
# Got data from year: 2001, page: 4.
# Not enough useful data on year: 2001, page: 5.
# Not enough useful data on year: 2001, page: 6.
# Multiple pages w/o useful data, skipping the rest of 2001.
# Got data from year: 2002, page: 1.
# Got data from year: 2002, page: 2.
# Got data from year: 2002, page: 3.
# Got data from year: 2002, page: 4.
# Not enough useful data on year: 2002, page: 5.
# Not enough useful data on year: 2002, page: 6.
# Multiple pages w/o useful data, skipping the rest of 2002.
# Got data from year: 2003, page: 1.
# Got data from year: 2003, page: 2.
# Got data from year: 2003, page: 3.
# Got data from year: 2003, page: 4.
# Got data from year: 2003, page: 5.
# Not enough useful data on year: 2003, page: 6.
# Not enough useful data on year: 2003, page: 7.
# Multiple pages w/o useful data, skipping the rest of 2003.
# Got data from year: 2004, page: 1.
# Got data from year: 2004, page: 2.
# Got data from year: 2004, page: 3.
# Got data from year: 2004, page: 4.
# Got data from year: 2004, page: 5.
# Not enough useful data on year: 2004, page: 6.
# Not enough useful data on year: 2004, page: 7.
# Multiple pages w/o useful data, skipping the rest of 2004.
# Got data from year: 2005, page: 1.
# Got data from year: 2005, page: 2.
# Got data from year: 2005, page: 3.
# Got data from year: 2005, page: 4.
# Got data from year: 2005, page: 5.
# Not enough useful data on year: 2005, page: 6.
# Not enough useful data on year: 2005, page: 7.
# Multiple pages w/o useful data, skipping the rest of 2005.
# Got data from year: 2006, page: 1.
# Got data from year: 2006, page: 2.
# Got data from year: 2006, page: 3.
# Got data from year: 2006, page: 4.
# Got data from year: 2006, page: 5.
# Not enough useful data on year: 2006, page: 6.
# Not enough useful data on year: 2006, page: 7.
# Multiple pages w/o useful data, skipping the rest of 2006.
# Got data from year: 2007, page: 1.
# Got data from year: 2007, page: 2.
# Got data from year: 2007, page: 3.
# Got data from year: 2007, page: 4.
# Got data from year: 2007, page: 5.
# Got data from year: 2007, page: 6.
# Not enough useful data on year: 2007, page: 7.
# Not enough useful data on year: 2007, page: 8.
# Multiple pages w/o useful data, skipping the rest of 2007.
# Got data from year: 2008, page: 1.
# Got data from year: 2008, page: 2.
# Got data from year: 2008, page: 3.
# Got data from year: 2008, page: 4.
# Got data from year: 2008, page: 5.
# Not enough useful data on year: 2008, page: 6.
# Not enough useful data on year: 2008, page: 7.
# Multiple pages w/o useful data, skipping the rest of 2008.
# Got data from year: 2009, page: 1.
# Got data from year: 2009, page: 2.
# Got data from year: 2009, page: 3.
# Got data from year: 2009, page: 4.
# Got data from year: 2009, page: 5.
# Got data from year: 2009, page: 6.
# Not enough useful data on year: 2009, page: 7.
# Not enough useful data on year: 2009, page: 8.
# Multiple pages w/o useful data, skipping the rest of 2009.
# Got data from year: 2010, page: 1.
# Got data from year: 2010, page: 2.
# Got data from year: 2010, page: 3.
# Got data from year: 2010, page: 4.
# Got data from year: 2010, page: 5.
# Got data from year: 2010, page: 6.
# Not enough useful data on year: 2010, page: 7.
# Not enough useful data on year: 2010, page: 8.
# Multiple pages w/o useful data, skipping the rest of 2010.
# Got data from year: 2011, page: 1.
# Got data from year: 2011, page: 2.
# Got data from year: 2011, page: 3.
# Got data from year: 2011, page: 4.
# Got data from year: 2011, page: 5.
# Got data from year: 2011, page: 6.
# Got data from year: 2011, page: 7.
# Not enough useful data on year: 2011, page: 8.
# Not enough useful data on year: 2011, page: 9.
# Multiple pages w/o useful data, skipping the rest of 2011.
# Got data from year: 2012, page: 1.
# Got data from year: 2012, page: 2.
# Got data from year: 2012, page: 3.
# Got data from year: 2012, page: 4.
# Got data from year: 2012, page: 5.
# Got data from year: 2012, page: 6.
# Got data from year: 2012, page: 7.
# Not enough useful data on year: 2012, page: 8.
# Not enough useful data on year: 2012, page: 9.
# Multiple pages w/o useful data, skipping the rest of 2012.
# Got data from year: 2013, page: 1.
# Got data from year: 2013, page: 2.
# Got data from year: 2013, page: 3.
# Got data from year: 2013, page: 4.
# Got data from year: 2013, page: 5.
# Got data from year: 2013, page: 6.
# Got data from year: 2013, page: 7.
# Not enough useful data on year: 2013, page: 8.
# Not enough useful data on year: 2013, page: 9.
# Multiple pages w/o useful data, skipping the rest of 2013.
# Got data from year: 2014, page: 1.
# Got data from year: 2014, page: 2.
# Got data from year: 2014, page: 3.
# Got data from year: 2014, page: 4.
# Got data from year: 2014, page: 5.
# Got data from year: 2014, page: 6.
# Got data from year: 2014, page: 7.
# Got data from year: 2014, page: 8.
# Not enough useful data on year: 2014, page: 9.
# Not enough useful data on year: 2014, page: 10.
# Multiple pages w/o useful data, skipping the rest of 2014.
# Got data from year: 2015, page: 1.
# Got data from year: 2015, page: 2.
# Got data from year: 2015, page: 3.
# Got data from year: 2015, page: 4.
# Got data from year: 2015, page: 5.
# Got data from year: 2015, page: 6.
# Got data from year: 2015, page: 7.
# Got data from year: 2015, page: 8.
# Not enough useful data on year: 2015, page: 9.
# Not enough useful data on year: 2015, page: 10.
# Multiple pages w/o useful data, skipping the rest of 2015.
# Got data from year: 2016, page: 1.
# Got data from year: 2016, page: 2.
# Got data from year: 2016, page: 3.
# Got data from year: 2016, page: 4.
# Got data from year: 2016, page: 5.
# Got data from year: 2016, page: 6.
# Got data from year: 2016, page: 7.
# Got data from year: 2016, page: 8.
# Got data from year: 2016, page: 9.
# Not enough useful data on year: 2016, page: 10.
# Not enough useful data on year: 2016, page: 11.
# Multiple pages w/o useful data, skipping the rest of 2016.
# Got data from year: 2017, page: 1.
# Got data from year: 2017, page: 2.
# Got data from year: 2017, page: 3.
# Got data from year: 2017, page: 4.
# Got data from year: 2017, page: 5.
# Got data from year: 2017, page: 6.
# Got data from year: 2017, page: 7.
# Got data from year: 2017, page: 8.
# Got data from year: 2017, page: 9.
# Got data from year: 2017, page: 10.
# Not enough useful data on year: 2017, page: 11.
# Not enough useful data on year: 2017, page: 12.
# Multiple pages w/o useful data, skipping the rest of 2017.
# Got data from year: 2018, page: 1.
# Got data from year: 2018, page: 2.
# Got data from year: 2018, page: 3.
# Got data from year: 2018, page: 4.
# Got data from year: 2018, page: 5.
# Got data from year: 2018, page: 6.
# Got data from year: 2018, page: 7.
# Got data from year: 2018, page: 8.
# Got data from year: 2018, page: 9.
# Not enough useful data on year: 2018, page: 10.
# Not enough useful data on year: 2018, page: 11.
# Multiple pages w/o useful data, skipping the rest of 2018.
# Got data from year: 2019, page: 1.
# Got data from year: 2019, page: 2.
# Got data from year: 2019, page: 3.
# Got data from year: 2019, page: 4.
# Got data from year: 2019, page: 5.
# Got data from year: 2019, page: 6.
# Got data from year: 2019, page: 7.
# Got data from year: 2019, page: 8.
# Got data from year: 2019, page: 9.
# Got data from year: 2019, page: 10.
# Not enough useful data on year: 2019, page: 11.
# Not enough useful data on year: 2019, page: 12.
# Multiple pages w/o useful data, skipping the rest of 2019.
# Got data from year: 2020, page: 1.
# Got data from year: 2020, page: 2.
# Got data from year: 2020, page: 3.
# Got data from year: 2020, page: 4.
# Got data from year: 2020, page: 5.
# Got data from year: 2020, page: 6.
# Got data from year: 2020, page: 7.
# Got data from year: 2020, page: 8.
# Not enough useful data on year: 2020, page: 9.
# Not enough useful data on year: 2020, page: 10.
# Multiple pages w/o useful data, skipping the rest of 2020.
# Got data from year: 2021, page: 1.
# Got data from year: 2021, page: 2.
# Got data from year: 2021, page: 3.
# Got data from year: 2021, page: 4.
# Got data from year: 2021, page: 5.
# Got data from year: 2021, page: 6.
# Got data from year: 2021, page: 7.
# Got data from year: 2021, page: 8.
# Got data from year: 2021, page: 9.
# Got data from year: 2021, page: 10.
# Got data from year: 2021, page: 11.
# Got data from year: 2021, page: 12.
# Got data from year: 2021, page: 13.
# Got data from year: 2021, page: 14.
# Not enough useful data on year: 2021, page: 15.
# Not enough useful data on year: 2021, page: 16.
# Multiple pages w/o useful data, skipping the rest of 2021.
# Got data from year: 2022, page: 1.
# Got data from year: 2022, page: 2.
# Got data from year: 2022, page: 3.
# Got data from year: 2022, page: 4.
# Got data from year: 2022, page: 5.
# Got data from year: 2022, page: 6.
# Got data from year: 2022, page: 7.
# Got data from year: 2022, page: 8.
# Got data from year: 2022, page: 9.
# Got data from year: 2022, page: 10.
# Got data from year: 2022, page: 11.
# Got data from year: 2022, page: 12.
# Got data from year: 2022, page: 13.
# Got data from year: 2022, page: 14.
# Got data from year: 2022, page: 15.
# Got data from year: 2022, page: 16.
# Got data from year: 2022, page: 17.
# Got data from year: 2022, page: 18.
# Got data from year: 2022, page: 19.
# Got data from year: 2022, page: 20.
# Got data from year: 2022, page: 21.
# Got data from year: 2022, page: 22.
# Got data from year: 2022, page: 23.
# Not enough useful data on year: 2022, page: 24.
# Not enough useful data on year: 2022, page: 25.
# Multiple pages w/o useful data, skipping the rest of 2022.
# Got data from year: 2023, page: 1.
# Got data from year: 2023, page: 2.
# Got data from year: 2023, page: 3.
# Got data from year: 2023, page: 4.
# Got data from year: 2023, page: 5.
# Got data from year: 2023, page: 6.
# Got data from year: 2023, page: 7.
# Got data from year: 2023, page: 8.
# Got data from year: 2023, page: 9.
# Got data from year: 2023, page: 10.
# Got data from year: 2023, page: 11.
# Got data from year: 2023, page: 12.
# Got data from year: 2023, page: 13.
# Got data from year: 2023, page: 14.
# Got data from year: 2023, page: 15.
# Got data from year: 2023, page: 16.
# Got data from year: 2023, page: 17.
# Not enough useful data on year: 2023, page: 18.
# Not enough useful data on year: 2023, page: 19.
# Multiple pages w/o useful data, skipping the rest of 2023.

# %%
# assemble df
movie_df = pd.DataFrame({
    'Movie ID': movie_ids,
    'Title': movie_names,
    'Release Year': movie_release_yrs,
    'Popularity Score': movie_pops,
    'Average Rating': movie_vote_avgs,
    'Number of Ratings': movie_vote_counts
})

movie_df = movie_df.set_index('Movie ID')

# export
movie_df.to_csv('../Raw Data/2000s_US_IDs.csv')

movie_df
# Out:
#                                                 Title  Release Year  \
# Movie ID
# 9600                                Big Momma's House          2000
# 11688                        The Emperor's New Groove          2000
# 4247                                      Scary Movie          2000
# 98                                          Gladiator          2000
# 10867                                          Malena          2000
# ...                                               ...           ...
# 881164                               Boston Strangler          2023
# 722149                         Luther: The Fallen Sun          2023
# 844417                                        Marlowe          2023
# 1068141   Mighty Morphin Power Rangers: Once & Always          2023
# 872954                                    The Old Way          2023
#
#           Popularity Score  Average Rating  Number of Ratings
# Movie ID
# 9600                95.366             5.8               2095
# 11688               95.121             7.5               6003
# 4247                90.579             6.3               6240
# 98                  74.966             8.2              16701
# 10867               74.228             7.4               1961
# ...                    ...             ...                ...
# 881164              27.471             6.7                434
# 722149              27.272             6.8                672
# 844417              23.636             6.2                160
# 1068141             21.831             6.6                196
# 872954              21.762             6.0                110
#
# [3124 rows x 5 columns]

# %%
# code by Peter Solis

# %%
# code by Azi Farooquee

# %%
#this section pulls in movie details for each movie in the movie_df and stores those details in respective list

movid = []
budget = []
revenue = []
genre = []
releasedate = []
runtime = []

for i in range(len(movie_df)):
    try:
        mymovie = movie_df.index[i]
        params = {'api_key':api_key}
        detail_url  = f"https://api.themoviedb.org/3/movie/{mymovie}"

        detailresponse = requests.get(detail_url, params=params).json()
        budgetr = detailresponse["budget"]
        budget.append(budgetr)
        revenuer = detailresponse["revenue"]
        revenue.append(revenuer)
        releasedater = detailresponse["release_date"]
        releasedate.append(releasedater)
        runtimer = detailresponse["runtime"]
        runtime.append(runtimer)
        genrer = detailresponse["genres"] #this returns a list of dictionaries
        genre.append(genrer)
        movidr = detailresponse["id"]
        movid.append(movidr)
    except:
        print(f"Data error with movie {mymovie}")
        
    
print(len(budget))
print(len(revenue))
print(len(genre))
print(len(releasedate))
print(len(runtime))
# Out:
# 3124
# 3124
# 3124
# 3124
# 3124

# %%
#this section merges the movie details list into a dictionary to create a datafram
moviedetails_df = pd.DataFrame({
    "Movie ID": movid,
    "Budget": budget,
    "Revenue": revenue,
    "Genre": genre,
    "Release Date": releasedate,
    "Run Time": runtime
})

# %%
#show the movie details DF
moviedetails_df
# Out:
#       Movie ID     Budget    Revenue  \
# 0         9600   30000000  173959438
# 1        11688  100000000  169327687
# 2         4247   19000000  278019771
# 3           98  103000000  465361176
# 4        10867          0   14493284
# ...        ...        ...        ...
# 3119    881164          0          0
# 3120    722149          0          0
# 3121    844417   20000000    6262663
# 3122   1068141          0          0
# 3123    872954          0          0
#
#                                                   Genre Release Date  Run Time
# 0     [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...   2000-05-31        98
# 1     [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...   2000-12-15        78
# 2                        [{'id': 35, 'name': 'Comedy'}]   2000-07-07        88
# 3     [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...   2000-05-04       155
# 4                         [{'id': 18, 'name': 'Drama'}]   2000-03-16       109
# ...                                                 ...          ...       ...
# 3119  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...   2023-03-17       112
# 3120                      [{'id': 80, 'name': 'Crime'}]   2023-02-24       129
# 3121  [{'id': 9648, 'name': 'Mystery'}, {'id': 53, '...   2023-02-15       109
# 3122  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...   2023-04-19        59
# 3123                    [{'id': 37, 'name': 'Western'}]   2023-01-06        95
#
# [3124 rows x 6 columns]

# %%
#export moviedetails_df to csv file
moviedetails_df.to_csv("../Raw Data/movie_details.csv")

# %%
#This section creates respective lists to store first 3 actors per movie and directors

creditmovie = []
actor1_list = []
actor2_list = []
actor3_list = []
directorslist = []

for i in range(len(movie_df)):
    try:
        mymovie2 = movie_df.index[i]
        params = {'api_key':api_key}
        credit_url  = f"https://api.themoviedb.org/3/movie/{mymovie2}/credits"

        response3 = requests.get(credit_url, params=params).json()
        crmovier = response3["id"]
        creditmovie.append(crmovier)
        actor = response3["cast"][0]["name"]
        actor1_list.append(actor)
        actor = response3["cast"][1]["name"]
        actor2_list.append(actor)
        try:
            actor = response3["cast"][2]["name"]
            actor3_list.append(actor)
        except:
            actor3_list.append("null")

        for dirname in response3["crew"]:
            if dirname["job"].lower() == "director":
                director = dirname["name"]
                directorslist.append(director)
                break
    except IndexError:
        print(f"Index error with movie {mymovie}")
        
    
print(len(actor1_list))
print(len(actor2_list))
print(len(actor3_list))
print(len(directorslist))
# Out:
# 3124
# 3124
# 3124
# 3124

# %%
print(len(creditmovie))
# Out:
# 3124

# %%
#this section merges the movie credits list into a dictionary to create a datafram
moviecredits_df = pd.DataFrame({
    "Movie ID": creditmovie,
    "Actor 1": actor1_list,
    "Actor 2": actor2_list,
    "Actor 3": actor3_list,
    "Director": directorslist
})

# %%
#Preview the movie credits df
moviecredits_df.head(5)
# Out:
#    Movie ID          Actor 1           Actor 2           Actor 3  \
# 0      9600  Martin Lawrence          Nia Long     Paul Giamatti
# 1     11688      David Spade      John Goodman       Eartha Kitt
# 2      4247       Anna Faris      Jon Abrahams     Marlon Wayans
# 3        98    Russell Crowe   Joaquin Phoenix    Connie Nielsen
# 4     10867  Monica Bellucci  Giuseppe Sulfaro  Luciano Federico
#
#               Director
# 0         Raja Gosnell
# 1          Mark Dindal
# 2  Keenen Ivory Wayans
# 3         Ridley Scott
# 4   Giuseppe Tornatore

# %%
#export moviecredits_df to csv file
moviecredits_df.to_csv("../Raw Data/movie_credits.csv")

# %%
movie1 = movie_df.loc[[89636, 583055, 722913, 1010818, 938567]]
movie1
# Out:
#                                                       Title  Release Year  \
# Movie ID
# 89636     Dragon Ball Z: Plan to Eradicate the Super Sai...          2010
# 583055                          Spider-Ham: Caught in a Ham          2019
# 722913                                      Malcolm & Marie          2021
# 1010818                                 Groot's First Steps          2022
# 938567                 Teasing Master Takagi-san: The Movie          2022
#
#           Popularity Score  Average Rating  Number of Ratings
# Movie ID
# 89636               21.782             7.1                262
# 583055              20.251             6.9                192
# 722913              23.871             7.1               1276
# 1010818             47.106             7.0                288
# 938567              26.037             8.4                111

# %%
params = {'api_key':api_key}
base_url4  = f"https://api.themoviedb.org/3/movie/938567/credits"
response4 = requests.get(base_url4, params=params).json()
print(json.dumps(response4, indent=4))
# Out:
# {
#     "id": 938567,
#     "cast": [
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 149894,
#             "known_for_department": "Acting",
#             "name": "Yuki Kaji",
#             "original_name": "Yuki Kaji",
#             "popularity": 13.577,
#             "profile_path": "/8wKdPV11IwowfwoqGqMMNt9hmp6.jpg",
#             "cast_id": 1,
#             "character": "Nishikata (voice)",
#             "credit_id": "620a50a4ecbde90041aa09d9",
#             "order": 0
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 1492982,
#             "known_for_department": "Acting",
#             "name": "Rie Takahashi",
#             "original_name": "Rie Takahashi",
#             "popularity": 18.649,
#             "profile_path": "/6S7G3FZnma2vo4B8ODqAdbeRKda.jpg",
#             "cast_id": 2,
#             "character": "Takagi-san (voice)",
#             "credit_id": "620a50d2f48b34001b157292",
#             "order": 1
#         }
#     ],
#     "crew": [
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 73046,
#             "known_for_department": "Production",
#             "name": "Masakazu Kubo",
#             "original_name": "Masakazu Kubo",
#             "popularity": 1.441,
#             "profile_path": "/ptnm9QJQ8L6Zrf5Q6j0N7Vl8bwL.jpg",
#             "credit_id": "63cdb58209dda400cfd95af4",
#             "department": "Production",
#             "job": "Executive Producer"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 34928,
#             "known_for_department": "Visual Effects",
#             "name": "Toshihiko Masuda",
#             "original_name": "Toshihiko Masuda",
#             "popularity": 2.553,
#             "profile_path": null,
#             "credit_id": "63cdb971d363e50079c245c1",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 553062,
#             "known_for_department": "Writing",
#             "name": "Aki Itami",
#             "original_name": "Aki Itami",
#             "popularity": 1.964,
#             "profile_path": null,
#             "credit_id": "62345f378e8d3000783bc5c8",
#             "department": "Writing",
#             "job": "Screenplay"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 934825,
#             "known_for_department": "Visual Effects",
#             "name": "Aya Takano",
#             "original_name": "Aya Takano",
#             "popularity": 1.153,
#             "profile_path": null,
#             "credit_id": "62345e738e8d300047afe97f",
#             "department": "Visual Effects",
#             "job": "Character Designer"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 1352126,
#             "known_for_department": "Art",
#             "name": "Yuji Ikeda",
#             "original_name": "Yuji Ikeda",
#             "popularity": 0.949,
#             "profile_path": null,
#             "credit_id": "63cdb6a02d8ef300c8d1b3a5",
#             "department": "Art",
#             "job": "Art Designer"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 1460798,
#             "known_for_department": "Visual Effects",
#             "name": "Takuji Mogi",
#             "original_name": "Takuji Mogi",
#             "popularity": 1.231,
#             "profile_path": null,
#             "credit_id": "63cdb6869a643500872b760b",
#             "department": "Visual Effects",
#             "job": "Animation Director"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 1460798,
#             "known_for_department": "Visual Effects",
#             "name": "Takuji Mogi",
#             "original_name": "Takuji Mogi",
#             "popularity": 1.231,
#             "profile_path": null,
#             "credit_id": "63cdb5d12d8ef300afe06546",
#             "department": "Visual Effects",
#             "job": "Character Designer"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 1460798,
#             "known_for_department": "Visual Effects",
#             "name": "Takuji Mogi",
#             "original_name": "Takuji Mogi",
#             "popularity": 1.231,
#             "profile_path": null,
#             "credit_id": "63cdb7aed363e50086d3a972",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 1491329,
#             "known_for_department": "Camera",
#             "name": "Yuya Sakuma",
#             "original_name": "Yuya Sakuma",
#             "popularity": 1.4,
#             "profile_path": "/aY8qe0l3vNPp6fTFWmHSAlAEPtm.jpg",
#             "credit_id": "63cdbacc9a64350082548241",
#             "department": "Visual Effects",
#             "job": "Compositing Artist"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 1492982,
#             "known_for_department": "Acting",
#             "name": "Rie Takahashi",
#             "original_name": "Rie Takahashi",
#             "popularity": 18.649,
#             "profile_path": "/6S7G3FZnma2vo4B8ODqAdbeRKda.jpg",
#             "credit_id": "63cdb864d363e50079c24595",
#             "department": "Sound",
#             "job": "Theme Song Performance"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 1493763,
#             "known_for_department": "Sound",
#             "name": "Hiroaki Tsutsumi",
#             "original_name": "Hiroaki Tsutsumi",
#             "popularity": 1.4,
#             "profile_path": "/gjZTF2jtGqvGY4F6XywHCweVkMb.jpg",
#             "credit_id": "62345fd8ba131b007c03522a",
#             "department": "Sound",
#             "job": "Original Music Composer"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 1513249,
#             "known_for_department": "Production",
#             "name": "Reiko Sasaki",
#             "original_name": "Reiko Sasaki",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb6716d97e600b74deec0",
#             "department": "Production",
#             "job": "Producer"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 1540866,
#             "known_for_department": "Visual Effects",
#             "name": "Akiko Matsuo",
#             "original_name": "Akiko Matsuo",
#             "popularity": 1.156,
#             "profile_path": null,
#             "credit_id": "63cdb6979a643500ce1588e0",
#             "department": "Visual Effects",
#             "job": "Animation Director"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 1540866,
#             "known_for_department": "Visual Effects",
#             "name": "Akiko Matsuo",
#             "original_name": "Akiko Matsuo",
#             "popularity": 1.156,
#             "profile_path": null,
#             "credit_id": "63cdb91c336e0100879d73aa",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 1569489,
#             "known_for_department": "Visual Effects",
#             "name": "Toyohiro Okada",
#             "original_name": "Toyohiro Okada",
#             "popularity": 0.722,
#             "profile_path": null,
#             "credit_id": "63cdb9752d8ef300812664d9",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 1583479,
#             "known_for_department": "Visual Effects",
#             "name": "Noriyuki Tsutsumi",
#             "original_name": "Noriyuki Tsutsumi",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb8eee24b93009b9d368b",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 1583514,
#             "known_for_department": "Editing",
#             "name": "Yumiko Nakaba",
#             "original_name": "Yumiko Nakaba",
#             "popularity": 0.98,
#             "profile_path": null,
#             "credit_id": "63cdb6ac336e010084aa82fa",
#             "department": "Editing",
#             "job": "Editor"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 1649495,
#             "known_for_department": "Visual Effects",
#             "name": "Takuji Yoshimoto",
#             "original_name": "Takuji Yoshimoto",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb76ad363e500de101968",
#             "department": "Visual Effects",
#             "job": "Animation Director"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 1662436,
#             "known_for_department": "Camera",
#             "name": "Yukiko Nagase",
#             "original_name": "Yukiko Nagase",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdbad0d363e5008e8f7271",
#             "department": "Visual Effects",
#             "job": "Compositing Artist"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 1735178,
#             "known_for_department": "Sound",
#             "name": "Keiko Osaki",
#             "original_name": "Keiko Osaki",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb836336e0100a85575d6",
#             "department": "Sound",
#             "job": "Musician"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 1820199,
#             "known_for_department": "Sound",
#             "name": "Katsuhiro Nakano",
#             "original_name": "Katsuhiro Nakano",
#             "popularity": 0.84,
#             "profile_path": null,
#             "credit_id": "63cdb6b309dda4007a6d2012",
#             "department": "Sound",
#             "job": "Sound Effects"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 1832379,
#             "known_for_department": "Directing",
#             "name": "Hiroaki Akagi",
#             "original_name": "Hiroaki Akagi",
#             "popularity": 2.207,
#             "profile_path": null,
#             "credit_id": "62345e4a46aed4007b14371d",
#             "department": "Directing",
#             "job": "Director"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 1832379,
#             "known_for_department": "Directing",
#             "name": "Hiroaki Akagi",
#             "original_name": "Hiroaki Akagi",
#             "popularity": 2.207,
#             "profile_path": null,
#             "credit_id": "63cdb8866d97e600add4ec15",
#             "department": "Visual Effects",
#             "job": "Opening/Ending Animation"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 1832379,
#             "known_for_department": "Directing",
#             "name": "Hiroaki Akagi",
#             "original_name": "Hiroaki Akagi",
#             "popularity": 2.207,
#             "profile_path": null,
#             "credit_id": "63cdb77dcee48100dee9251f",
#             "department": "Art",
#             "job": "Storyboard Artist"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 1832379,
#             "known_for_department": "Directing",
#             "name": "Hiroaki Akagi",
#             "original_name": "Hiroaki Akagi",
#             "popularity": 2.207,
#             "profile_path": null,
#             "credit_id": "63cdb6102d8ef3007c6b2ed8",
#             "department": "Directing",
#             "job": "Second Unit Director"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 1845878,
#             "known_for_department": "Visual Effects",
#             "name": "Shinichiro Nagano",
#             "original_name": "Shinichiro Nagano",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdbab8e24b9300cdf98565",
#             "department": "Visual Effects",
#             "job": "Compositing Artist"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 1845879,
#             "known_for_department": "Camera",
#             "name": "Yukiko Kawai",
#             "original_name": "Yukiko Kawai",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb80509dda40095923f29",
#             "department": "Art",
#             "job": "Assistant Director of Photography"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 1922631,
#             "known_for_department": "Directing",
#             "name": "Juria Matsumura",
#             "original_name": "Juria Matsumura",
#             "popularity": 1.96,
#             "profile_path": null,
#             "credit_id": "63cdb62e09dda4008dd6e54f",
#             "department": "Directing",
#             "job": "Second Unit Director"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 2018865,
#             "known_for_department": "Visual Effects",
#             "name": "Satoru Koshiishi",
#             "original_name": "Satoru Koshiishi",
#             "popularity": 0.906,
#             "profile_path": null,
#             "credit_id": "63cdb96309dda400cfd95bd8",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 2032155,
#             "known_for_department": "Art",
#             "name": "Hitoshi Nagasaki",
#             "original_name": "Hitoshi Nagasaki",
#             "popularity": 1.4,
#             "profile_path": null,
#             "credit_id": "63cdb94fd363e5009d68a44f",
#             "department": "Art",
#             "job": "Background Designer"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 2032163,
#             "known_for_department": "Art",
#             "name": "Michiko Taniguchi",
#             "original_name": "Michiko Taniguchi",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb969cee481007cdd5e50",
#             "department": "Art",
#             "job": "Background Designer"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 2032198,
#             "known_for_department": "Art",
#             "name": "Yuki Kasahara",
#             "original_name": "Yuki Kasahara",
#             "popularity": 1.38,
#             "profile_path": null,
#             "credit_id": "63cdb69d9a64350082548144",
#             "department": "Art",
#             "job": "Art Direction"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 2032203,
#             "known_for_department": "Art",
#             "name": "Yuko Kobayashi",
#             "original_name": "Yuko Kobayashi",
#             "popularity": 0.989,
#             "profile_path": null,
#             "credit_id": "63cdb973d363e500de1019c7",
#             "department": "Art",
#             "job": "Background Designer"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 2044642,
#             "known_for_department": "Production",
#             "name": "Keiji Ota",
#             "original_name": "Keiji Ota",
#             "popularity": 2.758,
#             "profile_path": "/15NZaRqZHSguv6wF2SvuFoYlkiO.jpg",
#             "credit_id": "63cdb58c336e010084aa8296",
#             "department": "Production",
#             "job": "Executive Producer"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 2058545,
#             "known_for_department": "Visual Effects",
#             "name": "Chihiro Hayashi",
#             "original_name": "Chihiro Hayashi",
#             "popularity": 0.98,
#             "profile_path": null,
#             "credit_id": "63cdb96d6d97e600add4ec42",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 2085268,
#             "known_for_department": "Writing",
#             "name": "Soichiro Yamamoto",
#             "original_name": "Soichiro Yamamoto",
#             "popularity": 1.96,
#             "profile_path": null,
#             "credit_id": "62345f93894ed6007947e3ef",
#             "department": "Writing",
#             "job": "Comic Book"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 2085268,
#             "known_for_department": "Writing",
#             "name": "Soichiro Yamamoto",
#             "original_name": "Soichiro Yamamoto",
#             "popularity": 1.96,
#             "profile_path": null,
#             "credit_id": "63cdb799e24b930081947ac9",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 2160337,
#             "known_for_department": "Visual Effects",
#             "name": "Yoshihiro Maeda",
#             "original_name": "Yoshihiro Maeda",
#             "popularity": 1.112,
#             "profile_path": null,
#             "credit_id": "63cdb8fbe24b930081947b1c",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": true,
#             "gender": 2,
#             "id": 2210737,
#             "known_for_department": "Sound",
#             "name": "Takahiro Enomoto",
#             "original_name": "Takahiro Enomoto",
#             "popularity": 1.38,
#             "profile_path": null,
#             "credit_id": "63cdb6b0336e0100879d732d",
#             "department": "Sound",
#             "job": "Sound Director"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 2362529,
#             "known_for_department": "Visual Effects",
#             "name": "Kazunori Ozawa",
#             "original_name": "Kazunori Ozawa",
#             "popularity": 1.4,
#             "profile_path": null,
#             "credit_id": "63cdb908e24b93009edb138d",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 2378096,
#             "known_for_department": "Visual Effects",
#             "name": "Fumiya Uehara",
#             "original_name": "Fumiya Uehara",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb91909dda4007a6d2087",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 2378259,
#             "known_for_department": "Directing",
#             "name": "Yasuaki Fujii",
#             "original_name": "Yasuaki Fujii",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb7816d97e600add4ebf3",
#             "department": "Art",
#             "job": "Storyboard Artist"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 2378259,
#             "known_for_department": "Directing",
#             "name": "Yasuaki Fujii",
#             "original_name": "Yasuaki Fujii",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb614336e0100811967ac",
#             "department": "Directing",
#             "job": "Second Unit Director"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 2382136,
#             "known_for_department": "Writing",
#             "name": "Hiroko Fukuda",
#             "original_name": "Hiroko Fukuda",
#             "popularity": 1.4,
#             "profile_path": null,
#             "credit_id": "62345f2bd7cd06001cda2c1e",
#             "department": "Writing",
#             "job": "Screenplay"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 2382136,
#             "known_for_department": "Writing",
#             "name": "Hiroko Fukuda",
#             "original_name": "Hiroko Fukuda",
#             "popularity": 1.4,
#             "profile_path": null,
#             "credit_id": "62345ee7db4ed60073b28b95",
#             "department": "Writing",
#             "job": "Series Composition"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 2403219,
#             "known_for_department": "Visual Effects",
#             "name": "Masae Otake",
#             "original_name": "Masae Otake",
#             "popularity": 0.6,
#             "profile_path": "/3rhKlaiwuO4sb5e3RWVpL40Ku2R.jpg",
#             "credit_id": "63cdb77ae24b93009b9d3648",
#             "department": "Art",
#             "job": "Prop Designer"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 2403219,
#             "known_for_department": "Visual Effects",
#             "name": "Masae Otake",
#             "original_name": "Masae Otake",
#             "popularity": 0.6,
#             "profile_path": "/3rhKlaiwuO4sb5e3RWVpL40Ku2R.jpg",
#             "credit_id": "63cdbbce9a643500ce158a1d",
#             "department": "Visual Effects",
#             "job": "2D Artist"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 2428348,
#             "known_for_department": "Visual Effects",
#             "name": "Natsuko Kondou",
#             "original_name": "Natsuko Kondou",
#             "popularity": 0.652,
#             "profile_path": null,
#             "credit_id": "63cdb6839a643500ae03c905",
#             "department": "Visual Effects",
#             "job": "Animation Director"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 2428348,
#             "known_for_department": "Visual Effects",
#             "name": "Natsuko Kondou",
#             "original_name": "Natsuko Kondou",
#             "popularity": 0.652,
#             "profile_path": null,
#             "credit_id": "63cdb5d7cee48100c1df8328",
#             "department": "Visual Effects",
#             "job": "Character Designer"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 2428349,
#             "known_for_department": "Visual Effects",
#             "name": "Norikazu Kamibayashi",
#             "original_name": "Norikazu Kamibayashi",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb6f6cee481008eff1817",
#             "department": "Visual Effects",
#             "job": "CGI Director"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 2475020,
#             "known_for_department": "Visual Effects",
#             "name": "Sota Suwa",
#             "original_name": "Sota Suwa",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb7aacee48100c1df83af",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 2532800,
#             "known_for_department": "Visual Effects",
#             "name": "Emiko Nakano",
#             "original_name": "Emiko Nakano",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb9409a643500ce1589a4",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 2534605,
#             "known_for_department": "Production",
#             "name": "Ken Amano",
#             "original_name": "Ken Amano",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb65ae24b93009edb12dd",
#             "department": "Production",
#             "job": "Executive Producer"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 2594177,
#             "known_for_department": "Sound",
#             "name": "Tatsuhiro Amano",
#             "original_name": "Tatsuhiro Amano",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb82309dda40083852322",
#             "department": "Sound",
#             "job": "Sound Mixer"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 2649448,
#             "known_for_department": "Camera",
#             "name": "Masato Makino",
#             "original_name": "Masato Makino",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb6a4e24b93009edb1301",
#             "department": "Camera",
#             "job": "Director of Photography"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 2731482,
#             "known_for_department": "Visual Effects",
#             "name": "Jiro Majima",
#             "original_name": "Jiro Majima",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb97be24b93009edb13a3",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 2756635,
#             "known_for_department": "Production",
#             "name": "Michihiko Umezawa",
#             "original_name": "Michihiko Umezawa",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb59d336e01007c5ff514",
#             "department": "Production",
#             "job": "Executive Producer"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 2772496,
#             "known_for_department": "Visual Effects",
#             "name": "Saori Koike",
#             "original_name": "Saori Koike",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb9272d8ef3007c6b2f97",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 2794067,
#             "known_for_department": "Sound",
#             "name": "Yoshiki Kobayashi",
#             "original_name": "Yoshiki Kobayashi",
#             "popularity": 0.766,
#             "profile_path": null,
#             "credit_id": "63cdb6b76d97e600add4ebab",
#             "department": "Sound",
#             "job": "Music Producer"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 2798919,
#             "known_for_department": "Visual Effects",
#             "name": "Makiko Shinohara",
#             "original_name": "Makiko Shinohara",
#             "popularity": 1.153,
#             "profile_path": null,
#             "credit_id": "63cdb9126d97e600add4ec2c",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 2800859,
#             "known_for_department": "Production",
#             "name": "Kazutaka Yamanaka",
#             "original_name": "Kazutaka Yamanaka",
#             "popularity": 0.775,
#             "profile_path": null,
#             "credit_id": "63cdb66109dda400cfd95b49",
#             "department": "Production",
#             "job": "Executive Producer"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 2825122,
#             "known_for_department": "Visual Effects",
#             "name": "Ryuuta Ura",
#             "original_name": "Ryuuta Ura",
#             "popularity": 2.516,
#             "profile_path": null,
#             "credit_id": "63cdb90bcee481007cdd5e39",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 2842428,
#             "known_for_department": "Visual Effects",
#             "name": "Haruki Miura",
#             "original_name": "Haruki Miura",
#             "popularity": 0.664,
#             "profile_path": null,
#             "credit_id": "63cdb9156d97e6007c9e191c",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 2858495,
#             "known_for_department": "Sound",
#             "name": "Yuiko Ohara",
#             "original_name": "Yuiko Ohara",
#             "popularity": 0.68,
#             "profile_path": "/1XYtEQHdloNKsEOSFnp7CpU8CYl.jpg",
#             "credit_id": "63cdb85609dda40095923f40",
#             "department": "Sound",
#             "job": "Songs"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 2858495,
#             "known_for_department": "Sound",
#             "name": "Yuiko Ohara",
#             "original_name": "Yuiko Ohara",
#             "popularity": 0.68,
#             "profile_path": "/1XYtEQHdloNKsEOSFnp7CpU8CYl.jpg",
#             "credit_id": "626a4079489d0000524f606d",
#             "department": "Sound",
#             "job": "Theme Song Performance"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 2888815,
#             "known_for_department": "Visual Effects",
#             "name": "Yuji Shibata",
#             "original_name": "Yuji Shibata",
#             "popularity": 1.4,
#             "profile_path": null,
#             "credit_id": "63cdb939d363e5009d68a44a",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 2888997,
#             "known_for_department": "Visual Effects",
#             "name": "Akihiko Oka",
#             "original_name": "Akihiko Oka",
#             "popularity": 1.011,
#             "profile_path": null,
#             "credit_id": "63cdb689336e010084aa82ed",
#             "department": "Visual Effects",
#             "job": "Animation Director"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 2889001,
#             "known_for_department": "Visual Effects",
#             "name": "Yoshifumi Okawa",
#             "original_name": "Yoshifumi Okawa",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb74ee24b930089678874",
#             "department": "Visual Effects",
#             "job": "Animation Director"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 2912465,
#             "known_for_department": "Visual Effects",
#             "name": "Takumi Takatsuma",
#             "original_name": "Takumi Takatsuma",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb9512d8ef300843aabdd",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 2935156,
#             "known_for_department": "Writing",
#             "name": "Kanichi Kato",
#             "original_name": "Kanichi Kato",
#             "popularity": 1.22,
#             "profile_path": null,
#             "credit_id": "62345f4b894ed60046706ac8",
#             "department": "Writing",
#             "job": "Screenplay"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 2958529,
#             "known_for_department": "Visual Effects",
#             "name": "Yuta Ohara",
#             "original_name": "Yuta Ohara",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb693336e0100a855754c",
#             "department": "Visual Effects",
#             "job": "Animation Director"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 2958529,
#             "known_for_department": "Visual Effects",
#             "name": "Yuta Ohara",
#             "original_name": "Yuta Ohara",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb9356d97e600b74def53",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 2989627,
#             "known_for_department": "Visual Effects",
#             "name": "Erika Okada",
#             "original_name": "Erika Okada",
#             "popularity": 1.218,
#             "profile_path": null,
#             "credit_id": "63cdb920336e01007c5ff606",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 3025881,
#             "known_for_department": "Visual Effects",
#             "name": "Asato Ikumi",
#             "original_name": "Asato Ikumi",
#             "popularity": 0.615,
#             "profile_path": null,
#             "credit_id": "63cdb902e24b93009edb1389",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 3073897,
#             "known_for_department": "Visual Effects",
#             "name": "Hitomi Shimodaira",
#             "original_name": "Hitomi Shimodaira",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb94e2d8ef3009674a83b",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 3080294,
#             "known_for_department": "Visual Effects",
#             "name": "Chiemi Hironaka",
#             "original_name": "Chiemi Hironaka",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb777336e0100879d7369",
#             "department": "Art",
#             "job": "Prop Designer"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 3080294,
#             "known_for_department": "Visual Effects",
#             "name": "Chiemi Hironaka",
#             "original_name": "Chiemi Hironaka",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb5df6d97e60081ff7ee0",
#             "department": "Visual Effects",
#             "job": "Character Designer"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 3080294,
#             "known_for_department": "Visual Effects",
#             "name": "Chiemi Hironaka",
#             "original_name": "Chiemi Hironaka",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb93d336e01007c5ff60c",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 3089427,
#             "known_for_department": "Visual Effects",
#             "name": "Kanata Yanagisawa",
#             "original_name": "Kanata Yanagisawa",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb68d9a6435008abbdc65",
#             "department": "Visual Effects",
#             "job": "Animation Director"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 3089427,
#             "known_for_department": "Visual Effects",
#             "name": "Kanata Yanagisawa",
#             "original_name": "Kanata Yanagisawa",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb5db336e0100c8f35bae",
#             "department": "Visual Effects",
#             "job": "Character Designer"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 3089427,
#             "known_for_department": "Visual Effects",
#             "name": "Kanata Yanagisawa",
#             "original_name": "Kanata Yanagisawa",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb8ea336e01007c5ff5fc",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 3149241,
#             "known_for_department": "Visual Effects",
#             "name": "Shingo Nishiyama",
#             "original_name": "Shingo Nishiyama",
#             "popularity": 0.631,
#             "profile_path": null,
#             "credit_id": "63cdb9596d97e600add4ec3d",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 3160877,
#             "known_for_department": "Visual Effects",
#             "name": "Kazuhiro Itakura",
#             "original_name": "Kazuhiro Itakura",
#             "popularity": 0.982,
#             "profile_path": null,
#             "credit_id": "639f5d38be6d8800bca804f9",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 3201074,
#             "known_for_department": "Visual Effects",
#             "name": "Masahito Wada",
#             "original_name": "Masahito Wada",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb92ad363e50086d3a9b3",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 3202644,
#             "known_for_department": "Visual Effects",
#             "name": "Mitsuhime Nitta",
#             "original_name": "Mitsuhime Nitta",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb95c9a6435008deff84d",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 3220268,
#             "known_for_department": "Visual Effects",
#             "name": "Woo Geum-yung",
#             "original_name": "Woo Geum-yung",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "62b994c784f24903ec44a8e6",
#             "department": "Visual Effects",
#             "job": "Animation Director"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 3224479,
#             "known_for_department": "Visual Effects",
#             "name": "Yurika Tsushima",
#             "original_name": "Yurika Tsushima",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb8e7336e010084aa8385",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 3243223,
#             "known_for_department": "Visual Effects",
#             "name": "Kayo Daibou",
#             "original_name": "Kayo Daibou",
#             "popularity": 1.22,
#             "profile_path": null,
#             "credit_id": "63cdb955cee481007cdd5e47",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 3276820,
#             "known_for_department": "Production",
#             "name": "Mikito Bizenjima",
#             "original_name": "Mikito Bizenjima",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb6929a64350082548141",
#             "department": "Production",
#             "job": "Executive Producer"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 3300783,
#             "known_for_department": "Visual Effects",
#             "name": "Takayuki Sugiura",
#             "original_name": "Takayuki Sugiura",
#             "popularity": 0.656,
#             "profile_path": null,
#             "credit_id": "63cdb930e24b930081947b32",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 3326127,
#             "known_for_department": "Visual Effects",
#             "name": "Etsuo Nakashiro",
#             "original_name": "Etsuo Nakashiro",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb74809dda40095923f05",
#             "department": "Visual Effects",
#             "job": "Animation Director"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 3326127,
#             "known_for_department": "Visual Effects",
#             "name": "Etsuo Nakashiro",
#             "original_name": "Etsuo Nakashiro",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb92ecee48100a4486cea",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 3331706,
#             "known_for_department": "Visual Effects",
#             "name": "Izumi Kawada",
#             "original_name": "Izumi Kawada",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb8f59a6435008deff840",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 3335126,
#             "known_for_department": "Camera",
#             "name": "Tsubasa Kanamori",
#             "original_name": "Tsubasa Kanamori",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdbad3e24b93009edb13df",
#             "department": "Visual Effects",
#             "job": "Compositing Artist"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 3370835,
#             "known_for_department": "Production",
#             "name": "Kei Nishi",
#             "original_name": "Kei Nishi",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb65ee24b930081947a65",
#             "department": "Production",
#             "job": "Executive Producer"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 3378550,
#             "known_for_department": "Visual Effects",
#             "name": "Ruri Satou",
#             "original_name": "Ruri Satou",
#             "popularity": 0.6,
#             "profile_path": "/bQ7tuLVEb82U6xV8XVaCV0XmkXp.jpg",
#             "credit_id": "63cdbada336e0100811968a5",
#             "department": "Visual Effects",
#             "job": "Compositing Artist"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 3387138,
#             "known_for_department": "Visual Effects",
#             "name": "Yuki Bessho",
#             "original_name": "Yuki Bessho",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb7656d97e60089f0c040",
#             "department": "Visual Effects",
#             "job": "Animation Director"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 3387138,
#             "known_for_department": "Visual Effects",
#             "name": "Yuki Bessho",
#             "original_name": "Yuki Bessho",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb97e6d97e600add4ec4a",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 3396433,
#             "known_for_department": "Visual Effects",
#             "name": "Hitomi Aso",
#             "original_name": "Hitomi Aso",
#             "popularity": 0.84,
#             "profile_path": null,
#             "credit_id": "63cdb773cee48100a4486c9a",
#             "department": "Art",
#             "job": "Prop Designer"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 3396433,
#             "known_for_department": "Visual Effects",
#             "name": "Hitomi Aso",
#             "original_name": "Hitomi Aso",
#             "popularity": 0.84,
#             "profile_path": null,
#             "credit_id": "63cdb8f8e24b9300cdf98513",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 3397880,
#             "known_for_department": "Visual Effects",
#             "name": "Mizue Fukuda",
#             "original_name": "Mizue Fukuda",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb923e24b9300cdf9851f",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 3397906,
#             "known_for_department": "Visual Effects",
#             "name": "Chen Dali",
#             "original_name": "Chen Dali",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb61b2d8ef300afe06560",
#             "department": "Visual Effects",
#             "job": "Animation Director"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 3397906,
#             "known_for_department": "Visual Effects",
#             "name": "Chen Dali",
#             "original_name": "Chen Dali",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb79e6d97e60081ff7f73",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 3397906,
#             "known_for_department": "Visual Effects",
#             "name": "Chen Dali",
#             "original_name": "Chen Dali",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb6172d8ef300c8d1b379",
#             "department": "Directing",
#             "job": "Second Unit Director"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 3398259,
#             "known_for_department": "Directing",
#             "name": "Park Gyeong-sun",
#             "original_name": "Park Gyeong-sun",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb61e6d97e60081ff7ef6",
#             "department": "Directing",
#             "job": "Second Unit Director"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 3398313,
#             "known_for_department": "Visual Effects",
#             "name": "Sachi Takahashi",
#             "original_name": "Sachi Takahashi",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb9602d8ef300afe06600",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 3404947,
#             "known_for_department": "Directing",
#             "name": "Hiroki Imamura",
#             "original_name": "Hiroki Imamura",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb784336e01007c5ff5b4",
#             "department": "Art",
#             "job": "Storyboard Artist"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 3409991,
#             "known_for_department": "Art",
#             "name": "Yusuke Motokura",
#             "original_name": "Yusuke Motokura",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdbac22d8ef300afe06637",
#             "department": "Visual Effects",
# ...
#             "gender": 1,
#             "id": 3459878,
#             "known_for_department": "Visual Effects",
#             "name": "Sachiko Ito",
#             "original_name": "Sachiko Ito",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdbad76d97e600b74defa3",
#             "department": "Visual Effects",
#             "job": "Compositing Artist"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 3493796,
#             "known_for_department": "Visual Effects",
#             "name": "Mika Yokoi",
#             "original_name": "Mika Yokoi",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb69ae24b93009edb12fa",
#             "department": "Visual Effects",
#             "job": "Color Designer"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 3499794,
#             "known_for_department": "Production",
#             "name": "Ryo Fujita",
#             "original_name": "Ryo Fujita",
#             "popularity": 1.025,
#             "profile_path": null,
#             "credit_id": "63cdb5879a6435008abbdc10",
#             "department": "Production",
#             "job": "Executive Producer"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 3499952,
#             "known_for_department": "Visual Effects",
#             "name": "Tomomasa Ito",
#             "original_name": "Tomomasa Ito",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdbac5d363e50079c245fc",
#             "department": "Visual Effects",
#             "job": "Compositing Artist"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 3499953,
#             "known_for_department": "Visual Effects",
#             "name": "Yudai Higa",
#             "original_name": "Yudai Higa",
#             "popularity": 0.97,
#             "profile_path": null,
#             "credit_id": "63cdbadecee48100a4486d41",
#             "department": "Visual Effects",
#             "job": "Compositing Artist"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 3499954,
#             "known_for_department": "Visual Effects",
#             "name": "Kaito Ishizaka",
#             "original_name": "Kaito Ishizaka",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdbae109dda400838523ab",
#             "department": "Visual Effects",
#             "job": "Compositing Artist"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 3499955,
#             "known_for_department": "Visual Effects",
#             "name": "Natsu Nishioka",
#             "original_name": "Natsu Nishioka",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdbac86d97e600b74def9f",
#             "department": "Visual Effects",
#             "job": "Compositing Artist"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 3502386,
#             "known_for_department": "Directing",
#             "name": "Takuya Ogasawara",
#             "original_name": "Takuya Ogasawara",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdbbdacee4810084d4a348",
#             "department": "Visual Effects",
#             "job": "2D Artist"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 3502386,
#             "known_for_department": "Directing",
#             "name": "Takuya Ogasawara",
#             "original_name": "Takuya Ogasawara",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb6336d97e6008c25a03b",
#             "department": "Directing",
#             "job": "Second Unit Director"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 3503860,
#             "known_for_department": "Production",
#             "name": "Motomichi Araki",
#             "original_name": "Motomichi Araki",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb66709dda400838522a1",
#             "department": "Production",
#             "job": "Producer"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 3529362,
#             "known_for_department": "Visual Effects",
#             "name": "Kim Min-ja",
#             "original_name": "Kim Min-ja",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "62b994ccf031740d0e2d5fbd",
#             "department": "Visual Effects",
#             "job": "Animation Director"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 3531868,
#             "known_for_department": "Visual Effects",
#             "name": "Yuri Kotake",
#             "original_name": "Yuri Kotake",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb9479a643500872b7694",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 3531870,
#             "known_for_department": "Visual Effects",
#             "name": "Lee Ho-se",
#             "original_name": "Lee Ho-se",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdba09336e0100a8557630",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 3554844,
#             "known_for_department": "Production",
#             "name": "Yukari Nishikawa",
#             "original_name": "Yukari Nishikawa",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb67709dda4007a6d1ffb",
#             "department": "Production",
#             "job": "Associate Producer"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 3697959,
#             "known_for_department": "Camera",
#             "name": "Hiroshi Onishi",
#             "original_name": "Hiroshi Onishi",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdbab409dda40095923f9b",
#             "department": "Visual Effects",
#             "job": "Compositing Artist"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 3709742,
#             "known_for_department": "Production",
#             "name": "Shinichiro Mutaguchi",
#             "original_name": "Shinichiro Mutaguchi",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb57ecee481007cdd5d27",
#             "department": "Production",
#             "job": "Executive Producer"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 3710270,
#             "known_for_department": "Visual Effects",
#             "name": "Wang Xuanjing",
#             "original_name": "Wang Xuanjing",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb9326d97e600add4ec2f",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 3753200,
#             "known_for_department": "Visual Effects",
#             "name": "Yoshihiro Kajiwara",
#             "original_name": "Yoshihiro Kajiwara",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdbaae336e010081196893",
#             "department": "Visual Effects",
#             "job": "Compositing Artist"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 3767831,
#             "known_for_department": "Visual Effects",
#             "name": "Jazzline Monteron",
#             "original_name": "Jazzline Monteron",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb9439a643500ae03c9b8",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 3797084,
#             "known_for_department": "Visual Effects",
#             "name": "Ryoya Abe",
#             "original_name": "Ryoya Abe",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdbab1cee481007cdd5e82",
#             "department": "Visual Effects",
#             "job": "Compositing Artist"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 3797085,
#             "known_for_department": "Visual Effects",
#             "name": "Kengo Yanagisawa",
#             "original_name": "Kengo Yanagisawa",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdbabc2d8ef30081266515",
#             "department": "Visual Effects",
#             "job": "Compositing Artist"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 3829782,
#             "known_for_department": "Visual Effects",
#             "name": "Yoshiyuki Tokinaga",
#             "original_name": "Yoshiyuki Tokinaga",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb8ff336e010084aa838b",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 3845121,
#             "known_for_department": "Art",
#             "name": "Mai Sasaki",
#             "original_name": "Mai Sasaki",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb978d363e50086d3a9bd",
#             "department": "Art",
#             "job": "Background Designer"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 3845125,
#             "known_for_department": "Art",
#             "name": "Kayoko Fujiki",
#             "original_name": "Kayoko Fujiki",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb96109dda4008dd6e601",
#             "department": "Art",
#             "job": "Background Designer"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 3845126,
#             "known_for_department": "Art",
#             "name": "Kenta Sawatani",
#             "original_name": "Kenta Sawatani",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb955336e01007c5ff612",
#             "department": "Art",
#             "job": "Background Designer"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 3845135,
#             "known_for_department": "Art",
#             "name": "Junko Araki",
#             "original_name": "Junko Araki",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb965d363e500ba79081c",
#             "department": "Art",
#             "job": "Background Designer"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 3845141,
#             "known_for_department": "Art",
#             "name": "Harumi Suwa",
#             "original_name": "Harumi Suwa",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb94ae24b930081947b3a",
#             "department": "Art",
#             "job": "Background Designer"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 3860350,
#             "known_for_department": "Production",
#             "name": "Mitsuteru Hishiyama",
#             "original_name": "Mitsuteru Hishiyama",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb67d2d8ef300c8d1b38f",
#             "department": "Production",
#             "job": "Associate Producer"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 3881589,
#             "known_for_department": "Art",
#             "name": "Mizuki Nakano",
#             "original_name": "Mizuki Nakano",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb97c9a643500825481f4",
#             "department": "Art",
#             "job": "Background Designer"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 3886434,
#             "known_for_department": "Production",
#             "name": "Gou Inagaki",
#             "original_name": "Gou Inagaki",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb6bbcee481007cdd5da6",
#             "department": "Production",
#             "job": "Associate Producer"
#         },
#         {
#             "adult": false,
#             "gender": 2,
#             "id": 3886436,
#             "known_for_department": "Production",
#             "name": "Kentaro Kitani",
#             "original_name": "Kentaro Kitani",
#             "popularity": 1.38,
#             "profile_path": null,
#             "credit_id": "63cdb6d5e24b930081947a8c",
#             "department": "Production",
#             "job": "Associate Producer"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 3886439,
#             "known_for_department": "Visual Effects",
#             "name": "Jang Mi-hee",
#             "original_name": "Jang Mi-hee",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb782336e010084aa8346",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 3886440,
#             "known_for_department": "Visual Effects",
#             "name": "Hwang You-seon",
#             "original_name": "Hwang You-seon",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb78a09dda4008dd6e5c6",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 3886449,
#             "known_for_department": "Visual Effects",
#             "name": "Mayumi Shirakawa",
#             "original_name": "Mayumi Shirakawa",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdb910e24b930081947b2b",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 3886450,
#             "known_for_department": "Art",
#             "name": "Tomomi Fujiwara",
#             "original_name": "Tomomi Fujiwara",
#             "popularity": 0.98,
#             "profile_path": null,
#             "credit_id": "63cdb98cd363e500de1019d6",
#             "department": "Art",
#             "job": "Background Designer"
#         },
#         {
#             "adult": false,
#             "gender": 1,
#             "id": 3886451,
#             "known_for_department": "Visual Effects",
#             "name": "Rinko Hayashi",
#             "original_name": "Rinko Hayashi",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdba21d363e500de1019f5",
#             "department": "Visual Effects",
#             "job": "Key Animation"
#         },
#         {
#             "adult": false,
#             "gender": 0,
#             "id": 3886455,
#             "known_for_department": "Visual Effects",
#             "name": "Yuji Kumai",
#             "original_name": "Yuji Kumai",
#             "popularity": 0.6,
#             "profile_path": null,
#             "credit_id": "63cdbabb9a6435008abbdd3b",
#             "department": "Visual Effects",
#             "job": "Compositing Artist"
#         }
#     ]
# }

# %%
directors_df = pd.DataFrame({
    'Director': directorslist,
    'Movie ID': movie_df.index.values.tolist()
})
directors_df
# Out:
#           Director  Movie ID
# 0     Raja Gosnell      9600
# 1     Raja Gosnell     11688
# 2     Raja Gosnell      4247
# 3     Raja Gosnell        98
# 4     Raja Gosnell     10867
# ...            ...       ...
# 3119  Raja Gosnell    881164
# 3120  Raja Gosnell    722149
# 3121  Raja Gosnell    844417
# 3122  Raja Gosnell   1068141
# 3123  Raja Gosnell    872954
#
# [3124 rows x 2 columns]

# %%
for i in range(len(movie_df)):
    mymovie = movie_df.index[i]
    params = {'api_key':api_key}
    base_url5  = f"https://api.themoviedb.org/3/movie/{mymovie}/credits"
    
    for dirname in response3["crew"]:
        if dirname["job"].lower() == "director":
            director = dirname["name"]
            directorslist.append(director)

# %%
#This section creates various lists to store data on movie actors and directors
problem_movies = [89636, 583055, 722913, 1010818, 938567]
movieidlist = []
actor1_list = []
actor2_list = []
actor3_list = []
directorslist = []
loop = 0
for i in range(len(problem_movies)):
    try:
        mymovie = problem_movies[i]
        params = {'api_key':api_key}
        base_url3  = f"https://api.themoviedb.org/3/movie/{mymovie}/credits"

        response3 = requests.get(base_url3, params=params).json()
        crmov = response3["id"]
        movieidlist.append(crmov)
        actor = response3["cast"][0]["name"]
        actor1_list.append(actor)
        actor = response3["cast"][1]["name"]
        actor2_list.append(actor)
        try:
            actor = response3["cast"][2]["name"]
            actor3_list.append(actor)
        except:
            actor3_list.append("null")
        
        for dirname in response3["crew"]:
            if dirname["job"].lower() == "director":
                director = dirname["name"]
                directorslist.append(director)
                break
    except IndexError:
        print(f"Index error with movie {mymovie}")
        
    
print(actor1_list)
print(actor2_list)
print(actor3_list)
print(directorslist)
print(movieidlist)
# Out:
# ['Masako Nozawa', 'John Mulaney', 'John David Washington', 'Vin Diesel', 'Yuki Kaji']
# ['Ryou Horikawa', 'Aaron LaPlante', 'Zendaya', 'Fred Tatasciore', 'Rie Takahashi']
# ['null', 'null', 'null', 'null', 'null']
# ['Yoshihiro Ueda', 'Miguel Jiron', 'Sam Levinson', 'Kirsten Lepore', 'Hiroaki Akagi']
# [89636, 583055, 722913, 1010818, 938567]

# %%
problem_movies2 = [89636, 583055, 722913, 1010818, 938567]

for i in range(len(problem_movies2)):
    mymovie = problem_movies2[i]
    print(mymovie)
# Out:
# 89636
# 583055
# 722913
# 1010818
# 938567
